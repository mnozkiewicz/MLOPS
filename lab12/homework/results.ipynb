# %% [markdown]
# ### Dag graphs
#
# ![](images/dag_data_prep.png)
#
#
# ![](images/dag_training.png)

# %% [markdown]
# ## Dag executions
#
# ![](images/data_prep_execution.png)
#
#
# ![](images/training_execution.png)

# %% [markdown]
# ## Files on S3

# %%
# !aws --endpoint-url=http://localhost:4566 s3 ls
# Out:
# 2026-01-18 00:06:54 airflow-xcom
# 2026-01-18 00:06:56 datasets

# %%
# !aws --endpoint-url=http://localhost:4566 s3 ls s3://datasets/taxi_data/
# Out:
# 2026-01-18 00:16:29   49961641 yellow_tripdata_2024-01.parquet
# 2026-01-18 00:16:35   50349284 yellow_tripdata_2024-02.parquet
# 2026-01-18 00:16:40   60078280 yellow_tripdata_2024-03.parquet
# 2026-01-18 00:16:47   59133625 yellow_tripdata_2024-04.parquet
# 2026-01-18 00:16:53   62553128 yellow_tripdata_2024-05.parquet
# 2026-01-18 00:16:59   59859922 yellow_tripdata_2024-06.parquet
# 2026-01-18 00:17:05   52299432 yellow_tripdata_2024-07.parquet
# 2026-01-18 00:17:11   51067350 yellow_tripdata_2024-08.parquet
# 2026-01-18 00:17:17   61170186 yellow_tripdata_2024-09.parquet
# 2026-01-18 00:17:23   64346071 yellow_tripdata_2024-10.parquet
# 2026-01-18 00:17:30   60658709 yellow_tripdata_2024-11.parquet
# 2026-01-18 00:17:36   61524085 yellow_tripdata_2024-12.parquet

# %%
# !aws --endpoint-url=http://localhost:4566 s3 ls s3://datasets/processed_data/year=2024/
# Out:
#                            PRE month=1/
#                            PRE month=10/
#                            PRE month=11/
#                            PRE month=12/
#                            PRE month=2/
#                            PRE month=3/
#                            PRE month=4/
#                            PRE month=5/
#                            PRE month=6/
#                            PRE month=7/
#                            PRE month=8/
#                            PRE month=9/

# %%
# !aws --endpoint-url=http://localhost:4566 s3 ls s3://datasets/processed_data/year=2024/month=1/
# Out:
# 2026-01-18 00:16:31       7972 data.parquet

# %%
# !aws --endpoint-url=http://localhost:4566 s3 ls s3://datasets/ml_staging/2024/
# Out:
# 2026-01-18 00:18:15       8050 test.parquet
# 2026-01-18 00:18:15      20796 train.parquet

# %%
# !aws --endpoint-url=http://localhost:4566 s3 ls s3://datasets/models/
# Out:
# 2026-01-18 00:18:31     172985 model_random_forest.pkl
# 2026-01-18 00:18:36       3342 model_ridge.pkl
# 2026-01-18 00:18:31      23065 model_svm.pkl

# %% [markdown]
# ## Model metrics from Postgres

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("postgresql+psycopg2://airflow:airflow@localhost:5433/models_db")
df = pd.read_sql("SELECT * FROM model_metrics", engine)
df
# Out:
#    id              training_date     model_type  \
# 0   1 2026-01-17 23:18:38.059215          ridge
# 1   2 2026-01-17 23:18:38.059215          ridge
# 2   3 2026-01-17 23:18:38.059215          ridge
# 3   4 2026-01-17 23:18:38.059215  random_forest
# 4   5 2026-01-17 23:18:38.059215  random_forest
# 5   6 2026-01-17 23:18:38.059215  random_forest
# 6   7 2026-01-17 23:18:38.059215            svm
# 7   8 2026-01-17 23:18:38.059215            svm
# 8   9 2026-01-17 23:18:38.059215            svm
#
#                           hyperparameters           mae       mape  \
# 0                          {'alpha': 0.1}  77761.606015   0.731872
# 1                          {'alpha': 1.0}  85597.447126   0.783331
# 2                         {'alpha': 10.0}  76302.028019   0.706361
# 3    {'max_depth': 5, 'n_estimators': 50}   2830.148933   0.032452
# 4  {'max_depth': 10, 'n_estimators': 100}   2232.619265   0.023762
# 5  {'max_depth': 15, 'n_estimators': 200}   2237.299276   0.023240
# ...
