# %% [markdown]
# # Data and model testing

# %%
import os

# gets rid of irritating warnings
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %% [markdown]
# ## Data preprocessing and initial quality checking
#
# We will be using [booking.com reviews dataset](https://www.kaggle.com/datasets/jiashenliu/515k-hotel-reviews-data-in-europe?resource=download), with over 500 thousand reviews of hotels. They are either positive or negative, and we will focus on review sentiment. We have [hosted it on HuggingFace](https://huggingface.co/datasets/morgul10/booking_reviews), with just the relevant columns.
#
# We will start with loading the data and initial checks - a **smoke test** of the data. Aim is to understand our dataset, and to detect obvious and serious problems. It is always a necessary process in ML.
#
# Most basic checks, which should always be performed, are:
# - data length
# - column types
# - example rows
# - exact duplicates check
# - labels distributions (for supervised problems)
# - more specific checks depending on the modality, e.g. text lengths distribution in NLP

# %%
import matplotlib.pyplot as plt
import pandas as pd

from datasets import load_dataset


df_raw = load_dataset("morgul10/booking_reviews")["train"].to_pandas()
df_neg = df_raw["Negative_Review"].str.strip()
df_pos = df_raw["Positive_Review"].str.strip()

# %%
print("Total data length:", len(df_raw))
print("Negative reviews:", len(df_neg))
print("Positive reviews:", len(df_pos))
# Out:
# Total data length: 515738
# Negative reviews: 515738
# Positive reviews: 515738

# %%
print("Data types:")
display(df_raw.dtypes)
# Out:
# Data types:
# Negative_Review    object
# Positive_Review    object
# dtype: object

# %%
print("First rows:")
display(df_raw.head(10))
# Out:
# First rows:
#                                      Negative_Review  \
# 0   I am so angry that i made this post available...
# 1                                        No Negative
# 2   Rooms are nice but for elderly a bit difficul...
# 3   My room was dirty and I was afraid to walk ba...
# 4   You When I booked with your company on line y...
# 5   Backyard of the hotel is total mess shouldn t...
# 6   Cleaner did not change our sheet and duvet ev...
# 7   Apart from the price for the brekfast Everyth...
# 8   Even though the pictures show very clean room...
# 9   The aircondition makes so much noise and its ...
#
#                                      Positive_Review
# 0   Only the park outside of the hotel was beauti...
# 1   No real complaints the hotel was great great ...
# 2   Location was good and staff were ok It is cut...
# 3   Great location in nice surroundings the bar a...
# 4    Amazing location and building Romantic setting
# 5   Good restaurant with modern design great chil...
# 6   The room is spacious and bright The hotel is ...
# 7   Good location Set in a lovely park friendly s...
# 8                                        No Positive
# 9   The room was big enough and the bed is good T...

# %%
print("Last rows:")
display(df_raw.tail(10))
# Out:
# Last rows:
#                                           Negative_Review  \
# 515728                                         Everything
# 515729                                        No Negative
# 515730   no free parking the room was in another build...
# 515731   No parking Public parking garage is 15 Euro p...
# 515732                                        No Negative
# 515733   no trolly or staff to help you take the lugga...
# 515734           The hotel looks like 3 but surely not 4
# 515735   The ac was useless It was a hot week in vienn...
# 515736                                        No Negative
# 515737       I was in 3rd floor It didn t work Free Wife
#
#                                           Positive_Review
# 515728                                            Nothing
# 515729   The breakfast was excelent lots of fress frui...
# 515730                                         large room
# 515731                                     Good breakfast
# 515732   helpful staff allowed me to check in early as...
# 515733                                           location
# 515734      Breakfast was ok and we got earlier check in
# 515735                                        No Positive
# 515736   The rooms are enormous and really comfortable...
# 515737                               staff was very kind

# %%
df_neg.str.len().plot.hist(title="Negative reviews lengths")
# Out:
# <Axes: title={'center': 'Negative reviews lengths'}, ylabel='Frequency'>

# %%
df_pos.str.len().plot.hist(title="Positive reviews lengths")
# Out:
# <Axes: title={'center': 'Positive reviews lengths'}, ylabel='Frequency'>

# %% [markdown]
# As you can see, the data contains quite a few "No Negatives" and "No Positive" rows. This is a widespread problem with "empty" rows, which are not really empty. They can take a form of:
# - default text, like we have here (frequent in automated forms, data from web scraping etc.)
# - empty string instead of NULL
# - deleted rows, but only marked with "deleted" column (frequent in data warehouses)
#
# Those problems can also crop up during inference (e.g., empty text), and should be handled properly.
#
# This is a particular instance of **duplicate data** problem, which is surprisingly common. Another reason may be that people writing texts don't care, e.g. input generic answers like "ok" or "everything". This biases the model, essentially putting more weights on those texts. Worse, they can have different labels, which introduces strong noise.
#
# Let's see how frequent is this problem.

# %% [markdown]
# ### Exercise 1 (1 point)
#
# Check the percentage of 20 most common text duplicates. This can be achieved with Pandas code conceptually similar to a combination of GROUP BY and COUNT aggregation. Check it:
# - in positive and negative subsets
# - for the whole dataset

# %%
def percentage_of_common_duplicates(s: pd.Series) -> str:
    fraction = s.groupby(s).count().sort_values(ascending=False)[:20].sum() / len(s)
    return f"{(100 * fraction):.2f}"

print("Percentage of 20 most common duplicates for:")
print(f"Negative reviews: {percentage_of_common_duplicates(df_neg)}%")
print(f"Positive reviews: {percentage_of_common_duplicates(df_pos)}%")

all_reviews = pd.concat([df_neg, df_pos], axis=0)
print(f"All reviews: {percentage_of_common_duplicates(all_reviews)}%")
# Out:
# Percentage of 20 most common duplicates for:
# Negative reviews: 30.56%
# Positive reviews: 11.79%
# All reviews: 20.77%

# %% [markdown]
# ### Manual data cleaning

# %% [markdown]
# Imagine training (and testing!) a model on data, where about 25% of negative class is duplicated, or has useless values like "none". Not a good idea, so we will remove those duplicates simply by using a case-insensitive regular expression. We will also remove words like "breakfast" or "location," which do not discriminate at all between positive and negative sentiment.

# %%
to_remove = [
    "No Negative", "No Positive", "nothing", "nothing really", "none", "n a", "na",
    "everything", "location", "the location", "breakfast", "the breakfast", "staff",
]
to_remove = [f"^{word}$" for word in to_remove]
to_remove = "|".join(to_remove)
to_remove
# Out:
# '^No Negative$|^No Positive$|^nothing$|^nothing really$|^none$|^n a$|^na$|^everything$|^location$|^the location$|^breakfast$|^the breakfast$|^staff$'

# %% [markdown]
# We will also perform two common cleaning steps: deduplication and removing empty strings. We can safely assume that people are lazy and write short, generic reviews, so there will be quite a few duplicates even after removing the most obvious cases.

# %%
df_neg_filtered = df_neg[~df_neg.str.contains(to_remove, case=False, na=True, regex=True)]
df_pos_filtered = df_pos[~df_pos.str.contains(to_remove, case=False, na=True, regex=True)]

# empty strings removal
df_neg_filtered = df_neg_filtered[df_neg_filtered.str.len() > 0]
df_pos_filtered = df_pos_filtered[df_pos_filtered.str.len() > 0]

df_neg_filtered = df_neg_filtered.reset_index(drop=True)
df_pos_filtered = df_pos_filtered.reset_index(drop=True)

df_neg_filtered = df_neg_filtered.to_frame().rename(columns={"Negative_Review": "text"})
df_pos_filtered = df_pos_filtered.to_frame().rename(columns={"Positive_Review": "text"})

df_neg_filtered["label"] = 0
df_pos_filtered["label"] = 1

print("Negative samples after filtering:", len(df_neg_filtered))
print("Positive samples after filtering:", len(df_pos_filtered))

df_all = pd.concat([df_neg_filtered, df_pos_filtered], ignore_index=True)
df_all = df_all.drop_duplicates(ignore_index=True)
# Out:
# Negative samples after filtering: 359750
# Positive samples after filtering: 459388

# %% [markdown]
# Lastly, we have quite a lot of data, so we'll randomly subsample it. We will use stratification, so that the label distribution will be the same after sampling.
#
# **Modify this** depending on your hardware. Very good GPU should handle up to ~100k samples, medium-grade GPU about ~10-50k, and CPU about 5k. The more samples you process, the better the results will be.

# %%
from sklearn.utils import resample

SAMPLES = 50_000
df = resample(df_all, replace=False, n_samples=SAMPLES, random_state=0, stratify=df_all["label"])
df = df.reset_index(drop=True)
df
# Out:
#                                                     text  label
# 0                       Rooftop pool and bar sensational      1
# 1                                      But I did like it      0
# 2      great place and location nice and quiet yet in...      1
# 3      The bar staff were just awful and painfully sl...      0
# 4      My sister I brought my dad for his 70th birthd...      1
# ...                                                  ...    ...
# 49995                                Everyone everything      1
# 49996           Loved the breakfast Catered for everyone      1
# 49997  The kindness of the staff and the service Also...      1
# 49998  Bit hectic at breakfast Had to ask for tea and...      0
# 49999  Lovely staff lovely hotel I was upgraded to a ...      1
#
# [50000 rows x 2 columns]

# %% [markdown]
# ## CleanLab blackbox testing
#
# [CleanLab library](https://github.com/cleanlab/cleanlab) aims to provide a blackbox, dead simple to use solution to ensure data quality. It can clean both data and labels, and works for any models. It is based on the framework of **confident learning (CL)**, originally created for detecting problems with data annotations.
#
# The main idea is as follows. A reasonably good model trained on the data should be very confident about properly annotated texts, and uncertain about ambiguous or incorrectly annotated texts. This is measured by predicted class probabilities. There are, of course, more details (e.g., class-conditioning, distinguishing model and data errors), but the general idea is really simple, and works with any data modality. It can not only detect errors, but also fix them. If another label is predicted with very high confidence, there is a high chance it's the correct one.
#
# ![flowchart.png](attachment:17e1aba2-573a-4693-a4a8-6d3f5ee8883a.png)
#
# Researchers in confidence learning, and creators of CleanLab, used this methodology in paper ["Pervasive label errors in test sets destabilize machine learning benchmarks" C.G. Northcutt et al](https://arxiv.org/abs/2103.14749). They showed that in popular text and image benchmarking datasets, up to 10% of labels are incorrect.
#
# We will take a similar approach to test our dataset. To avoid a chicken-and-egg problem (we don't have a model yet, but we need model probabilities), we need the **initial model**. A simple, yet effective approach is using a pretrained embedding model, combined with a linear classifier. This method is equivalent to freezing weights and training just the classifier head. Both embeddings and probability predictions are then used by CleanLab to detect problems.
#
# For text classification, the workflow recommended by [HuggingFace Open-Source AI Cookbook](https://huggingface.co/learn/cookbook/en/issues_in_text_dataset) is:
# 1. Compute text embeddings with a pretrained Sentence Transformer for feature extraction
# 2. Train logistic regression with cross-validation
# 3. Gather predicted probabilities (model confidence scores) for validation sets
# 4. Use CleanLab using this data
#
# Bonus: we originally detected some problems with duplicates in this dataset also by using CleanLab.

# %% [markdown]
# ### Exercise 2 (1 point)
#
# Implement the `get_initial_model_data()` function:
# 1. Compute text embeddings with [sentence-transformers](https://sbert.net/docs/sentence_transformer/pretrained_models.html) and `all-MiniLM-L6-v2` model.
# 2. Create `LogisticRegression` object
# 3. Train logistic regression and get probability predictions using `cross_val_predict()`. Note that it requires explicitly specifying that `predict_proba()` method should be used, in order to return probabilities, rather than 0/1 labels.

# %%
import joblib
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_predict

def get_initial_model_data(texts: np.ndarray, labels: np.ndarray) -> tuple[np.ndarray, np.ndarray]:

    embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
    embeddings = embedding_model.encode(texts)
    pred_probs = cross_val_predict(LogisticRegression(), embeddings, labels, method='predict_proba')

    return embeddings, pred_probs

# %% [markdown]
# #### Verification

# %%
texts = df["text"].values
labels = df["label"].values

embeddings, pred_probs = get_initial_model_data(texts, labels)

# %% [markdown]
# And now, we can use the CleanLab with the obtained embeddings and probability predictions.

# %%
from cleanlab import Datalab


data_dict = {"texts": texts, "labels": labels}
lab = Datalab(data_dict, label_name="labels", task="classification")
lab.find_issues(pred_probs=pred_probs, features=embeddings)
lab.report()
# Out:
# Finding null issues ...
# Finding label issues ...
# Finding outlier issues ...
# Finding near_duplicate issues ...
# Finding non_iid issues ...
# Finding class_imbalance issues ...
# Finding underperforming_group issues ...
#
# Audit complete. 1951 issues found in the dataset.
# Dataset Information: num_examples: 50000, num_classes: 2
#
# Here is a summary of various issues found in your data:
#
#     issue_type  num_issues
#          label        1047
# near_duplicate         592
#        outlier         312
#
# Learn about each issue: https://docs.cleanlab.ai/stable/cleanlab/datalab/guide/issue_type_description.html
# See which examples in your dataset exhibit each issue via: `datalab.get_issues(<ISSUE_NAME>)`
#
# Data indices corresponding to top examples of each issue are shown below.
#
#
# ----------------------- label issues -----------------------
#
# About this issue:
# 	Examples whose given label is estimated to be potentially incorrect
#     (e.g. due to annotation error) are flagged as having label issues.
#
#
# Number of examples with this issue: 1047
# Overall dataset quality in terms of this issue: 0.9836
#
# Examples representing most severe instances of this issue:
#        is_label_issue  label_score  given_label  predicted_label
# 12046            True     0.000167            0                1
# 5936             True     0.000240            0                1
# 11040            True     0.000307            0                1
# 23876            True     0.000320            0                1
# 21349            True     0.000429            1                0
#
#
# ------------------ near_duplicate issues -------------------
#
# About this issue:
# 	A (near) duplicate issue refers to two or more examples in
#     a dataset that are extremely similar to each other, relative
#     to the rest of the dataset.  The examples flagged with this issue
#     may be exactly duplicated, or lie atypically close together when
#     represented as vectors (i.e. feature embeddings).
#
#
# Number of examples with this issue: 592
# Overall dataset quality in terms of this issue: 0.5997
#
# Examples representing most severe instances of this issue:
#        is_near_duplicate_issue  near_duplicate_score near_duplicate_sets  distance_to_nearest_neighbor
# 47371                     True                   0.0             [30688]                           0.0
# 9785                      True                   0.0               [857]                           0.0
# 7411                      True                   0.0             [40642]                           0.0
# 2243                      True                   0.0             [11050]                           0.0
# 27134                     True                   0.0             [21018]                           0.0
#
#
# ---------------------- outlier issues ----------------------
#
# About this issue:
# 	Examples that are very different from the rest of the dataset
#     (i.e. potentially out-of-distribution or rare/anomalous instances).
#
#
# Number of examples with this issue: 312
# Overall dataset quality in terms of this issue: 0.3876
#
# Examples representing most severe instances of this issue:
#        is_outlier_issue  outlier_score
# 11961              True       0.062080
# 39586              True       0.068000
# 18650              True       0.068067
# 3918               True       0.074187
# 21964              True       0.076175

# %% [markdown]
# About 1.9% of duplicates, even after our cleaning, are quite expected. Many people don't really care and write short, generic reviews. Still, the data-driven approach confirms it, and we'll take a closer look at this. Additionally, about 2.2% of mislabeled data looks quite problematic.
#
# To programmatically inspect a given issue, `.get_issues()` method is used. For a given issue type (see report above for exact names), it returns a DataFrame with score for each sample. Lower score means higher risk of problems. It also returns a column with a boolean indicator whether a given sample has the problem, e.g. `is_near_duplicate_issue` or `is_label_issue`, which uses a default threshold for the score.
#
# Let's inspect the duplicate issues for now.

# %%
duplicate_issues = lab.get_issues("near_duplicate")
duplicate_issues = duplicate_issues[duplicate_issues["is_near_duplicate_issue"]]
duplicate_issues = duplicate_issues.sort_values(by="near_duplicate_score")

# %% [markdown]
# Row index indicates the row with a problem, and `near_duplicate_sets` are indices of duplicate rows. `distance_to_nearest_neighbor` measures distance between embeddings. Let's see the top 10 cases with most obvious duplicates.

# %%
for idx, row in duplicate_issues.head(10).iterrows():
    text = texts[idx]
    neighbors = texts[row["near_duplicate_sets"][:3]]
    print(f"Text: {text}")
    print(f"\tDuplicates: {neighbors}")
    print()
# Out:
# Text: IT WAS A BIT EXPENSIVE
# 	Duplicates: ['It was a bit expensive']
#
# Text: The tv
# 	Duplicates: ['The TV']
#
# Text: room size and location
# 	Duplicates: ['Room size and location']
#
# Text: the room wasn t clean
# 	Duplicates: ['The room wasn t clean' 'The room was not clean']
#
# Text: Room Location
# 	Duplicates: ['room location']
#
# Text: Everything was ok
# 	Duplicates: ['everything was OK']
#
# Text: It was a bit expensive
# 	Duplicates: ['IT WAS A BIT EXPENSIVE']
#
# Text: Very good Breakfast
# 	Duplicates: ['Very Good breakfast']
#
# Text: small rooms
# 	Duplicates: ['Small rooms' 'Smallish Rooms']
#
# Text: Everything in General
# 	Duplicates: ['everything in general']

# %% [markdown]
# Yeah, we forgot that `Pandas` is case-sensitive about finding duplicates. So with CleanLab, we identified a problem with our preprocessing. We will filter this in just a bit. Let's also see the last 10 duplicates.

# %%
for idx, row in duplicate_issues.tail(10).iterrows():
    text = texts[idx]
    neighbors = texts[row["near_duplicate_sets"][:3]]
    print(f"Text: {text}")
    print(f"\tDuplicates: {neighbors}")
    print()
# Out:
# Text: The staff was great friendly very helpful
# 	Duplicates: ['The staff were excellent friendly and very helpful']
#
# Text: great location and nice hotel
# 	Duplicates: ['Nice hotel Great location']
#
# Text: Comfortable bed nice helpful staff
# 	Duplicates: ['Very comfortable bed helpful friendly staff']
#
# Text: Very comfortable bed helpful friendly staff
# 	Duplicates: ['Comfortable bed nice helpful staff']
#
# Text: Good location and very clean comfortable rooms
# 	Duplicates: ['good location clean and comfortable rooms']
#
# Text: good location clean and comfortable rooms
# 	Duplicates: ['Good location and very clean comfortable rooms']
#
# Text: Location great Friendly staff
# 	Duplicates: ['Location fantastic friendly staff']
#
# Text: Location fantastic friendly staff
# 	Duplicates: ['Location great Friendly staff']
#
# Text: staff was extremely helpful and very nice
# 	Duplicates: ['Staff was great Very helpful and nice']
#
# Text: Staff was great Very helpful and nice
# 	Duplicates: ['staff was extremely helpful and very nice']

# %% [markdown]
# Definitely similar, but not exactly duplicates. We will remove the case-insensitive duplicates now. Note that we will keep the index to avoid recalculation for inspecting further issues.

# %%
df["text_lower"] = df["text"].str.lower()
df_deduplicated = df.drop_duplicates(subset="text_lower")
df_deduplicated = df_deduplicated.drop(columns="text_lower")
df_deduplicated = df_deduplicated.reset_index(drop=True)
df_deduplicated
# Out:
#                                                     text  label
# 0                       Rooftop pool and bar sensational      1
# 1                                      But I did like it      0
# 2      great place and location nice and quiet yet in...      1
# 3      The bar staff were just awful and painfully sl...      0
# 4      My sister I brought my dad for his 70th birthd...      1
# ...                                                  ...    ...
# 49935                                Everyone everything      1
# 49936           Loved the breakfast Catered for everyone      1
# 49937  The kindness of the staff and the service Also...      1
# 49938  Bit hectic at breakfast Had to ask for tea and...      0
# 49939  Lovely staff lovely hotel I was upgraded to a ...      1
#
# [49940 rows x 2 columns]

# %% [markdown]
# Now we will inspect labels. If our model predicts the label different from the real one with very high confidence, it may be a mislabeled sample.

# %%
label_issues = lab.get_issues("label")
label_issues = label_issues[label_issues["is_label_issue"]]
label_issues = label_issues.sort_values(by="label_score")

top_label_issues_y_true = label_issues.head(10)["given_label"]
top_label_issues_y_pred = label_issues.head(10)["predicted_label"]
top_label_issues_idxs = label_issues.head(10).index
top_label_issues_texts = texts[top_label_issues_idxs]

print("Top 10 label issues")
for text, y_true, y_pred in zip(top_label_issues_texts, top_label_issues_y_true, top_label_issues_y_pred):
    print(f"y_true {y_true}, y_pred {y_pred}, text: {text}")
    print()
# Out:
# Top 10 label issues
# y_true 0, y_pred 1, text: Staff very happy and friendly and vey helpful
#
# y_true 0, y_pred 1, text: Great location and convenient to transportation facilities
#
# y_true 0, y_pred 1, text: Excellent staff lovely
#
# y_true 0, y_pred 1, text: great location staff food and service
#
# y_true 1, y_pred 0, text: There was a problem with the bath water not hot enough but it was solved immediately
#
# y_true 1, y_pred 0, text: Booking not carried through as the hotel decided the price was too low Lack of communication from the hotel not even an apology
#
# y_true 0, y_pred 1, text: Fantastic location and good value for money
#
# y_true 1, y_pred 0, text: Bedroom needs painting there was a gap between bedroom carpet and bathroom door the bin in room was as all bent to different shapes stain on the table and seat In all the management need to invest heavily in the property Bedroom needs painting there was a gap between bedroom carpet and bathroom door the bin in room was as all bent to different shapes stain on the table and seat In all the management need to invest heavily in the property Bedroom needs painting there was a gap between bedroom carpet and bathroom door the bin in room was as all bent to different shapes stain on the table and seat In all the management need to invest heavily in the property Bedroom needs painting there was a gap between bedroom carpet and bathroom door the bin in room was as all bent to different shapes stain on the table and seat In all the management need to invest heavily in the property Bedroom needs painting there was a gap between bedroom carpet and bathroom door the bin in room was as all bent to different shapes stain on the table and seat In all the management need to invest heavily in the property Bedroom needs painting there was a gap between bedroom carpet and bathroom door the bin in room was as all bent to different shapes stain on the table and seat In all the management need to invest heavily in the property Bedroom needs painting there was a gap between bedroom carpet and bathroom door the bin in room was as all bent to different shapes stain on the table and seat In all the management need to invest heavily in the property Bedroom needs painting there was a gap between bedroom carpet and bathroom door the bin in room was as all bent to different shapes stain on the table and seat
#
# y_true 0, y_pred 1, text: Great family attitude
#
# y_true 0, y_pred 1, text: Nice hotel and location

# %% [markdown]
# The reason for those is most probably that on booking.com there are separate fields for positive and negative reviews. Some people may get confused and put texts in the wrong place. So we also identified a potential UX issue, in addition to the labeling problem.
#
# We will change the labels as suggested by CleanLab.

# %%
# make sure we don't get key errors - we removed some rows earlier during deduplication
label_issues = label_issues[label_issues.index.isin(df_deduplicated.index)]

idxs = label_issues.index.tolist()
pred_labels = label_issues["predicted_label"]

df_fixed = df_deduplicated.copy()
df_fixed.loc[idxs, "label"] = pred_labels
df_fixed
# Out:
#                                                     text  label
# 0                       Rooftop pool and bar sensational      1
# 1                                      But I did like it      0
# 2      great place and location nice and quiet yet in...      1
# 3      The bar staff were just awful and painfully sl...      0
# 4      My sister I brought my dad for his 70th birthd...      1
# ...                                                  ...    ...
# 49935                                Everyone everything      1
# 49936           Loved the breakfast Catered for everyone      1
# 49937  The kindness of the staff and the service Also...      1
# 49938  Bit hectic at breakfast Had to ask for tea and...      0
# 49939  Lovely staff lovely hotel I was upgraded to a ...      1
#
# [49940 rows x 2 columns]

# %% [markdown]
# ### Exercise 3 (1 point)
#
# 1. Print texts from the rows marked as outliers (`outlier` problem) with the strongest confidence (i.e., the lowest score).
# 2. Comment, do you think those samples really are strange? Would you remove them?

# %%
outlier_issues = lab.get_issues("outlier")
outlier_issues = outlier_issues[outlier_issues["is_outlier_issue"]].sort_values(by="outlier_score")

top_outliers = outlier_issues.head(10)

# %%
for index in top_outliers.index:
    print(f"Review: {texts[index]}, label: {labels[index]}")
# Out:
# Review: Change type of below, label: 0
# Review: Just not that crazy about Linz, label: 0
# Review: Julio is the man, label: 1
# Review: Personal bem ht aber nicht gut ausgebildet, label: 1
# Review: It s a tad hipstery but that s who they re aiming for I assume, label: 0
# Review: Thatbi oreder champangenon arriva and it wasn t there Had to remind but was sorted quickly, label: 0
# Review: Sorry wasn t anticipating this question have just answered it on the last question, label: 0
# Review: Shoild have a better agreement with peaking, label: 0
# Review: H rd s ng var enda minus under vistelsen, label: 0
# Review: Parkeren, label: 0

# %% [markdown]
# Well, most of the reviews did not seem to convey any information wheter the hotel was good or not, since our task is sentiment analysis then those kinds of reviews should probably be removed.
# The first one looks like some kind of mistake that occured when someone was posting the review and probably clicked something wrong. Some of them are in german and others just have spelling errors, so maybe instead of immediately removing them, a better next step would be to use a model for correcting spelling errors.

# %% [markdown]
# # Model Quality Testing
# This stage is essential for assessing the robustness, reliability, and performance of AI models developed using the curated data. Model Quality Testing enables us to verify that the model meets the intended goals and performs well across various scenarios and data subsets. This not only scrutinizes the accuracy and efficiency of models but also ensures that they are fair, accountable, and transparent in their operations.

# %% [markdown]
# ## Common metrics
#
# Now that our data is cleaned and prepared, we can train a model and proceed to test it. Firstly, we will just look at common numerical metrics, summarizing the model performance over test data. Further, we will perform **behavioral testing**, checking its stability, biases and other problems not visible when just using typical performance metrics on labels.
#
# Firstly, we will focus on just regular metrics, which use predicted probabilities and labels. Our dataset is relatively balanced, which is quite rarely the case. In any case, metrics that take label imbalance into consideration are a good choice. Well-known ones are:
# 1. Precision: if the model predicts the positive class, precision measures how sure we can be that it's really the positive class. High precision means low fraction of false positives (FP).
# 2. Recall: measures how much of the positive class the model detected. High recall means low fraction of false negatives (FN).
# 3. F1-score: a harmonic mean of precision and recall, aggregates them into one number for convenience. Harmonic mean heavily penalizes small numbers, so to get high value, both precision and recall have to be high, not just one of those.
#
# Area Under Receiver Operating Characteristic (AUROC / ROC AUC) is less frequently used in NLP, but has a few beneficial properties. It takes into consideration model probability predictions. For different thresholds (percentage above which we assume positive class) we measure the fractions of true positives and false positives, and aggregate those numbers. To achieve high AUROC, the model has to predict the right class with high probability, and avoid false positives even for low thresholds.
#
# Matthews Correlation Coefficient (MCC) can be thought of as Pearson correlation, but for binary variables. It has favorable statistical properties, and can spot model failures even when accuracy or AUROC are high. In particular, high MCC guarantees high AUROC and typically also other metrics, but not the other way around. For details, see:
# - [Wikipedia summary](https://en.wikipedia.org/wiki/Phi_coefficient#Advantages_over_accuracy_and_F1_score)
# - ["Ten quick tips for machine learning in computational biology" D. Chicco](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5721660/)
# - ["The advantages of the Matthews correlation coefficient (MCC) over F1 score and accuracy in binary classification evaluation" D. Chicco, G. Jurman](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6941312/)
# - ["The Matthews correlation coefficient (MCC) should replace the ROC AUC as the standard metric for assessing binary classification" D. Chicco, G. Jurman](https://biodatamining.biomedcentral.com/articles/10.1186/s13040-023-00322-4)
#
# Furthermore, any probabilistic metric like AUROC requires **well-calibrated** models, i.e. predicting probabilities right. Optimizing cross-entropy (log-loss) directly uses class probabilities, therefore logistic regression and neural networks typically are well-calibrated. Tree-based models, Naive Bayes or SVMs are often surprisingly bad at predicting probabilities. If a model is well-calibrated, we can trust that the probability it predicts is close to the true (typically unknown) probability.

# %% [markdown]
# ### Training a classifier
#
# We will fine-tune a simple [DistilBERT](https://huggingface.co/distilbert/distilbert-base-uncased) model (uncased variant) for binary classification. This is a typical HuggingFace code for training. We will evaluate the resulting model on many metrics, to gain more insight into its performance. During training, we will measure MCC every 1000 steps, to check how the training is progressing.

# %%
import torch
from datasets import Dataset, DatasetDict
from sklearn.model_selection import train_test_split


# 60-10-30% split
test_size = int(0.3 * len(df_fixed))
train_size = int(0.6 * len(df_fixed))

df_train, df_test = train_test_split(df_fixed, test_size=test_size, random_state=0, stratify=df_fixed["label"])
df_train, df_valid = train_test_split(df_train, train_size=train_size, random_state=0, stratify=df_train["label"])

datasets_dict = DatasetDict()
datasets_dict["train"] = Dataset.from_pandas(df_train, split="train")
datasets_dict["valid"] = Dataset.from_pandas(df_valid, split="valid")
datasets_dict["test"] = Dataset.from_pandas(df_test, split="test")

# %%
from transformers import AutoTokenizer


tokenizer = AutoTokenizer.from_pretrained("distilbert/distilbert-base-uncased")


def tokenize(examples: dict) -> dict:
    encoded_examples = tokenizer(examples["text"], padding=True, truncation=True)
    encoded_examples["label"] = torch.tensor(examples["label"])
    return encoded_examples


num_cores = joblib.cpu_count(only_physical_cores=True)
datasets_tokenized = datasets_dict.map(tokenize, batched=True)
# Out:
# Map:   0%|          | 0/29964 [00:00<?, ? examples/s]
# Map:   0%|          | 0/4994 [00:00<?, ? examples/s]
# Map:   0%|          | 0/14982 [00:00<?, ? examples/s]

# %%
import os
import random

from sklearn.metrics import matthews_corrcoef
from torch.nn.functional import softmax
from transformers import AutoModelForSequenceClassification, EvalPrediction, Trainer, TrainingArguments


# set determinism settings
os.environ["PYTHONHASHSEED"] = str(0)
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
torch.cuda.manual_seed_all(0)
# torch.mps.manual_seed(0)

model = AutoModelForSequenceClassification.from_pretrained("distilbert/distilbert-base-uncased", num_labels=2)


# freeze some weights to speed up training
for param in model.distilbert.embeddings.parameters():
    param.requires_grad = False

for param in model.distilbert.transformer.parameters():
    param.requires_grad = False


def compute_metrics(eval_pred: EvalPrediction) -> dict:
    y_true = eval_pred.label_ids.ravel()
    logits = torch.from_numpy(eval_pred.predictions)
    y_pred_proba = softmax(logits, dim=1)[:, 1].numpy()
    y_pred = (y_pred_proba >= 0.5).astype(int)
    mcc = matthews_corrcoef(y_true, y_pred)
    return {"MCC": mcc}


training_args = TrainingArguments(
    output_dir="finetuned_model",
    # change num_train_epochs depending on your hardware
    # if lower, increase learning rate and decrease save_steps and eval_steps
    learning_rate=1e-2,
    num_train_epochs=1,
    eval_strategy="steps",
    save_steps=500,
    eval_steps=500,
    save_total_limit=1,
    load_best_model_at_end=True,
    seed=0,
    data_seed=0,
    fp16=False,  # comment this out if you have unsupported hardware
    bf16=True,
    dataloader_num_workers=1,  # comment out if necessary
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=datasets_tokenized["train"],
    eval_dataset=datasets_tokenized["valid"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert/distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='3746' max='3746' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3746/3746 11:34, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Mcc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.444300</td>
#       <td>0.364289</td>
#       <td>0.793262</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.316400</td>
#       <td>0.246698</td>
#       <td>0.832208</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.269800</td>
#       <td>0.375433</td>
#       <td>0.814373</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.304700</td>
#       <td>0.237257</td>
#       <td>0.842734</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.262400</td>
#       <td>0.242865</td>
#       <td>0.843971</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.259600</td>
#       <td>0.230883</td>
#       <td>0.848753</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.259300</td>
#       <td>0.240250</td>
#       <td>0.851828</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=3746, training_loss=0.2995665173955735, metrics={'train_runtime': 695.6218, 'train_samples_per_second': 43.075, 'train_steps_per_second': 5.385, 'total_flos': 3045226794003456.0, 'train_loss': 0.2995665173955735, 'epoch': 1.0})

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, precision_score, recall_score, roc_auc_score


pred_output = trainer.predict(datasets_tokenized["test"])
logits = torch.from_numpy(pred_output.predictions)
y_pred_proba = softmax(logits, dim=1)[:, 1].numpy()
y_pred = (y_pred_proba >= 0.5).astype(int)
y_test = np.array(datasets_tokenized["test"]["label"])

print(f"Precision: {precision_score(y_test, y_pred):.2%}")
print(f"Recall: {recall_score(y_test, y_pred):.2%}")
print(f"F1-score: {f1_score(y_test, y_pred):.2%}")
print(f"AUROC: {roc_auc_score(y_test, y_pred_proba):.2%}")
print(f"MCC: {matthews_corrcoef(y_test, y_pred):.2%}")
# Out:
# Precision: 94.40%
# Recall: 91.84%
# F1-score: 93.10%
# AUROC: 96.91%
# MCC: 84.95%

# %% [markdown]
# Generally, we seem to have a quite good classifier, but a significantly lower MCC may indicate some problems. Although, we have to remember that these are just aggregate numbers, and may lead to wrong conclusions. Let's inspect some predictions manually.
#
# The simplest way to check is to do something similar to CleanLab label check. We take the predicted probabilities and check the test instances where:
# - the model predicted the lowest probability for the positive class, or the highest probability for the negative class
# - where the model was the most uncertain, i.e., the probability was closest to 50%

# %% [markdown]
# ### Exercise 4 (1 point)
#
# From test data, select:
# - Ten worst false positives (with the highest predicted probability, where the true class is negative)
# - Ten worst false negatives (with the lowest predicted probability among the truly positive class)
# - Ten most uncertain predictions (with probability closest to 50%)
#
# Do you see any obvious problems here?

# %%
mask = (y_test == 0)
idx = np.argsort(y_pred_proba[mask])[-10:]
real_index = np.where(mask)[0][idx]

for index in real_index:
    print(datasets_dict["test"]["text"][index])
# Out:
# Wonderful and super helpful staff Super close to Duomo square practically 50 steps away Great breakfast the sauna and gym facilities were a super bonus
# Location is great The rooms are neat and clean and the staff is very friendly and helpful
# Amenities were excellent Comfy room Reception and concierge staff were great
# Very clean and tidy perfect location spacious rooms and luminous Bathroom was big and clean as well as the kitchen area
# Lovely room with very comfortable bed Friendly and helpful staff Good food at breakfast with wide range to choose from High quality meals in the restaurant and pleasant ambience Hotel is situated in an attractive and safe area of the city
# Great location and convenient to transportation facilities
# Great 24 hour reception and friendly staff Clean and comfortable room
# Wonderful location next to all the sights opera museums We had a wonderful large room with every luxurious facility and furnishing Polite and helpful concierge and staff
# Friendly and knowledgeable
# Visited with family for wedding anniversary Great location wonderful use of art colour and architecture warm and friendly staff extremely comfy beds great breakfast all in all a wonderful venue and we shall revisit

# %%
mask = (y_test == 1)
idx = np.argsort(y_pred_proba[mask])[:10]
real_index = np.where(mask)[0][idx]

for index in real_index:
    print(datasets_dict["test"]["text"][index])
# Out:
# Wifi was not working room not cleaned rubbished from bin was left on desk top and when complained staff told us to put in bin
# terrible sound which lasted like 4 hours from 11 3am sounded like a piping water issue No1 on reception to alert as was quite late Meant i couldn t sleep
# Too expensive in breakfast and 65 Eur for parking per day
# Paper cups in the room didn t quite match the tone of the establishment
# Problems with the room 2 out of 3 nights no power Had to change room just for sleeping and showering No apologies nothing Too expensive for a room you don t even have room to put one bag
# the bathroom has disgusting smell
# A bit too hot with window closed
# The only reason I didn t give a 10 10 is that for the price I d expect a breakfast to be included not 17 extra a person Also their is only parking for around 30 cars
# I was upgraded from a single to a double room but the double room was very small and was basically a double mattress on two single bed frames There wasnt enough room to swing a cat I m not a very big person but had to walk sideways past the bed to get to the bathroom
# They forgot to make up our bedroom there was total confusion about a 15 credit we had to queue for breakfast and the shower was poor

# %%
idx = np.argsort(np.abs(y_pred_proba - 0.5))[:10]

for index in idx:
    print(datasets_dict["test"]["text"][index])
# Out:
# The cellphone conection is very low inside the hotel but hey you have free WiFi and an iMac in your room
# I was doing work in very center of London Soho so it was a 40 min tube drive in rush hour not that bad for London but if i was a tourist then this would not have been a problem Great hotel
# The brekfast
# The staff were nice in general The cleaning lady was such a sweetheart Sadly I forgot to ask her name but still would like to say it she only gave us some extra teas but she was sweet and helpful about it Short haired young lady with fair skin and brownish hair
# The suite was a bit cramped once the sofa bed was open and a cot set up
# The room upgrade location and style of the room
# Big room Bath tub
# this is not a 4 star hotel needs refurbishments Too expensive for present sittuation
# for us a longer stay
# common kitchen area would be nice

# %% [markdown]
# For the first two cases it obviously lookes like label mismatch. For the uncertain cases, some of the opinions contain both pros and cons for a hotel it is impossible to classify an opinion as strictly positive or negative.

# %% [markdown]
# ## Behavioral testing with Giskard
#
# [Giskard](https://github.com/Giskard-AI/giskard) is a library for testing tabular, NLP, vision models, and LLMs. It can detect issues like over- and underconfidence, unfairness (sensitivity to gender, religion, etc.), bias towards certain words or segments, etc. There are easily usable integrations with scikit-learn, HuggingFace or LangChain.
#
# It mostly relies on **slicing** and **input perturbation** techniques. Slicing analyzes model performance in slices (segments) e.g. when specific words appear. Input perturbations (also called transformations) slightly modify the input data and compare the model behavior between original and perturbed data. These can be introducing typos, lower- or uppercase, changing gender and religion words etc.
#
# Giskard requires passing a prediction function, which takes raw test data and returns model predictions, as well as a few other configuration elements. Importantly, if we want interpretable perturbations, we need to pass raw texts as inputs, so that they can be modified. Therefore, the embedding calculation needs to be inside this prediction function. We also use the logistic classifier trained above.
#
# **Warning:** this can take a bit. If it takes too long, you can subsample the test set to make it smaller.

# %%
from giskard import Model as GiskardModel, Dataset as GiskardDataset, scan, testing
from transformers import pipeline

trained_model = trainer.model
trained_model.eval()
model_pipeline = pipeline(
    "text-classification", 
    model=trained_model, 
    tokenizer=tokenizer,
    device="mps" if torch.backends.mps.is_available() else "cpu",
)


@torch.no_grad()
def prediction_function(df: pd.DataFrame) -> np.ndarray:
    pred_output = model_pipeline(df["text"].tolist())
    y_pred_proba = [pred["score"] for pred in pred_output]
    return y_pred_proba
# Out:
# Device set to use mps

# %%
giskard_dataset = GiskardDataset(df_test, target="label")

giskard_model = GiskardModel(
    model=prediction_function,
    model_type="classification",
    classification_labels=[0, 1],
    feature_names=["text"],
)
scan_results = scan(giskard_model, giskard_dataset, verbose=False)
display(scan_results)
# Out:
# 2025-11-15 01:12:21,240 pid:91984 MainThread giskard.datasets.base INFO     Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# 2025-11-15 01:12:21,241 pid:91984 MainThread giskard.models.automodel INFO     Your 'prediction_function' is successfully wrapped by Giskard's 'PredictionFunctionModel' wrapper class.
# 2025-11-15 01:12:21,246 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:12:21,326 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (10, 2) executed in 0:00:00.083287
# 2025-11-15 01:12:21,329 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:12:21,336 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009539
# 2025-11-15 01:12:21,339 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:12:21,340 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (10, 2) executed in 0:00:00.003308
# 2025-11-15 01:12:21,374 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,022 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (14982, 2) executed in 0:01:17.680616
# Your model is successfully validated.
# 2025-11-15 01:13:39,024 pid:91984 MainThread giskard.scanner.logger INFO     Running detectors: ['DataLeakageDetector', 'EthicalBiasDetector', 'TextPerturbationDetector', 'NumericalPerturbationDetector', 'OverconfidenceDetector', 'UnderconfidenceDetector', 'SpuriousCorrelationDetector', 'PerformanceBiasDetector', 'StochasticityDetector']
# 2025-11-15 01:13:39,024 pid:91984 MainThread giskard.scanner.logger INFO     DataLeakageDetector: Running
# 2025-11-15 01:13:39,040 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,045 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (14982, 2) executed in 0:00:00.021261
# 2025-11-15 01:13:39,049 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,060 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.011926
# 2025-11-15 01:13:39,062 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,068 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007093
# 2025-11-15 01:13:39,070 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,077 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008082
# 2025-11-15 01:13:39,079 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,086 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007741
# 2025-11-15 01:13:39,088 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,095 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007971
# 2025-11-15 01:13:39,097 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,105 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009019
# 2025-11-15 01:13:39,107 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,116 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009698
# 2025-11-15 01:13:39,117 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,126 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008582
# 2025-11-15 01:13:39,127 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,135 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008447
# 2025-11-15 01:13:39,136 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,146 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009907
# 2025-11-15 01:13:39,148 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,157 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.010174
# 2025-11-15 01:13:39,159 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,168 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009251
# 2025-11-15 01:13:39,169 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,184 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.015161
# 2025-11-15 01:13:39,185 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,194 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009557
# 2025-11-15 01:13:39,196 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,205 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009274
# 2025-11-15 01:13:39,206 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,217 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.011169
# 2025-11-15 01:13:39,218 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,227 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008586
# 2025-11-15 01:13:39,228 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,237 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008696
# 2025-11-15 01:13:39,238 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,248 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.010198
# 2025-11-15 01:13:39,250 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,259 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009584
# 2025-11-15 01:13:39,260 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,269 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009068
# 2025-11-15 01:13:39,270 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,285 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.014515
# 2025-11-15 01:13:39,286 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,295 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009566
# 2025-11-15 01:13:39,297 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,308 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.011632
# 2025-11-15 01:13:39,309 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,320 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.011149
# 2025-11-15 01:13:39,322 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,330 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009056
# 2025-11-15 01:13:39,332 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,344 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.012336
# 2025-11-15 01:13:39,345 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,354 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009200
# 2025-11-15 01:13:39,355 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,366 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.011071
# 2025-11-15 01:13:39,368 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,376 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008715
# 2025-11-15 01:13:39,377 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,385 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007627
# 2025-11-15 01:13:39,386 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,394 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007752
# 2025-11-15 01:13:39,395 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,403 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007608
# 2025-11-15 01:13:39,404 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,411 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007342
# 2025-11-15 01:13:39,412 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,421 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008643
# 2025-11-15 01:13:39,422 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,430 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008095
# 2025-11-15 01:13:39,431 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,440 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009510
# 2025-11-15 01:13:39,442 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,450 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008919
# 2025-11-15 01:13:39,451 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,460 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008855
# 2025-11-15 01:13:39,462 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,469 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008003
# 2025-11-15 01:13:39,470 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,479 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008549
# 2025-11-15 01:13:39,480 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,489 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008766
# 2025-11-15 01:13:39,490 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,500 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.010052
# 2025-11-15 01:13:39,501 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,510 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009012
# 2025-11-15 01:13:39,511 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,521 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.010306
# 2025-11-15 01:13:39,522 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,532 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009468
# 2025-11-15 01:13:39,533 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,541 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008226
# 2025-11-15 01:13:39,542 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,552 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.010249
# 2025-11-15 01:13:39,553 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,562 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008748
# 2025-11-15 01:13:39,563 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,577 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.014146
# 2025-11-15 01:13:39,579 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,586 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007535
# 2025-11-15 01:13:39,587 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,595 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007813
# 2025-11-15 01:13:39,596 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,603 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007413
# 2025-11-15 01:13:39,605 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,613 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008863
# 2025-11-15 01:13:39,615 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,625 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.010471
# 2025-11-15 01:13:39,626 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,636 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.010587
# 2025-11-15 01:13:39,638 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,646 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008046
# 2025-11-15 01:13:39,648 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,657 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.010279
# 2025-11-15 01:13:39,659 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,672 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.013493
# 2025-11-15 01:13:39,674 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,693 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.019190
# 2025-11-15 01:13:39,694 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,702 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008388
# 2025-11-15 01:13:39,703 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,713 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.010013
# 2025-11-15 01:13:39,715 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,724 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.010046
# 2025-11-15 01:13:39,726 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,737 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.011184
# 2025-11-15 01:13:39,738 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,748 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009908
# 2025-11-15 01:13:39,749 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,761 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.011927
# 2025-11-15 01:13:39,762 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,771 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009056
# 2025-11-15 01:13:39,772 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,780 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007950
# 2025-11-15 01:13:39,781 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,788 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006629
# 2025-11-15 01:13:39,789 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,795 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006838
# 2025-11-15 01:13:39,797 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,804 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007190
# 2025-11-15 01:13:39,805 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,812 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007489
# 2025-11-15 01:13:39,814 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,821 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007658
# 2025-11-15 01:13:39,823 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,829 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006879
# 2025-11-15 01:13:39,830 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,838 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007396
# 2025-11-15 01:13:39,839 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,846 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007689
# 2025-11-15 01:13:39,848 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,855 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007585
# 2025-11-15 01:13:39,857 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,864 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008226
# 2025-11-15 01:13:39,866 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,873 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007712
# 2025-11-15 01:13:39,875 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,882 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007945
# 2025-11-15 01:13:39,884 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,892 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008456
# 2025-11-15 01:13:39,893 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,902 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009471
# 2025-11-15 01:13:39,904 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,913 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009927
# 2025-11-15 01:13:39,915 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,924 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009345
# 2025-11-15 01:13:39,925 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,937 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.012122
# 2025-11-15 01:13:39,938 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,949 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.011216
# 2025-11-15 01:13:39,951 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,958 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007852
# 2025-11-15 01:13:39,960 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,968 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008891
# 2025-11-15 01:13:39,970 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,978 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008966
# 2025-11-15 01:13:39,980 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,989 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009985
# 2025-11-15 01:13:39,991 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:39,998 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007041
# 2025-11-15 01:13:39,999 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:40,006 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007791
# 2025-11-15 01:13:40,008 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:40,015 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007979
# 2025-11-15 01:13:40,017 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:40,024 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007486
# 2025-11-15 01:13:40,025 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:40,032 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007241
# 2025-11-15 01:13:40,033 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:40,041 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007921
# 2025-11-15 01:13:40,042 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:40,050 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008152
# 2025-11-15 01:13:40,051 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:40,058 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007376
# 2025-11-15 01:13:40,060 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:40,068 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008634
# 2025-11-15 01:13:40,069 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:40,086 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.016826
# 2025-11-15 01:13:40,087 pid:91984 MainThread giskard.scanner.logger INFO     EthicalBiasDetector: Running with transformations=['Switch Gender', 'Switch Religion', 'Switch countries from high- to low-income and vice versa'] threshold=None output_sensitivity=None num_samples=None
# 2025-11-15 01:13:52,896 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:52,897 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (782, 2) executed in 0:00:00.004340
# 2025-11-15 01:13:52,902 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:13:56,979 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (782, 2) executed in 0:00:04.081748
# 2025-11-15 01:13:56,980 pid:91984 MainThread giskard.scanner.logger INFO     EthicalBiasDetector: Testing `text` for perturbation `Switch Gender`	Fail rate: 0.000
# 2025-11-15 01:14:10,739 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:14:10,739 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (19, 2) executed in 0:00:00.001964
# 2025-11-15 01:14:10,741 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:14:10,881 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (19, 2) executed in 0:00:00.141737
# 2025-11-15 01:14:10,882 pid:91984 MainThread giskard.scanner.logger INFO     EthicalBiasDetector: Testing `text` for perturbation `Switch Religion`	Fail rate: 0.000
# 2025-11-15 01:14:45,761 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:14:45,762 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (200, 2) executed in 0:00:00.002633
# 2025-11-15 01:14:45,764 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:14:46,840 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (200, 2) executed in 0:00:01.077821
# 2025-11-15 01:14:46,840 pid:91984 MainThread giskard.scanner.logger INFO     EthicalBiasDetector: Testing `text` for perturbation `Switch countries from high- to low-income and vice versa`	Fail rate: 0.000
# 2025-11-15 01:14:46,841 pid:91984 MainThread giskard.scanner.logger INFO     TextPerturbationDetector: Running with transformations=['Transform to uppercase', 'Transform to lowercase', 'Transform to title case', 'Add typos', 'Punctuation Removal', 'Transform numbers to words', 'Accent Removal'] threshold=None output_sensitivity=None num_samples=None
# 2025-11-15 01:14:46,851 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:14:46,853 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:00.004286
# 2025-11-15 01:14:46,856 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:14:52,082 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:05.228519
# 2025-11-15 01:14:52,082 pid:91984 MainThread giskard.scanner.logger INFO     TextPerturbationDetector: Testing `text` for perturbation `Transform to uppercase`	Fail rate: 0.000
# 2025-11-15 01:14:52,092 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:14:52,093 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:00.004009
# 2025-11-15 01:14:52,096 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:14:57,246 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:05.152699
# 2025-11-15 01:14:57,246 pid:91984 MainThread giskard.scanner.logger INFO     TextPerturbationDetector: Testing `text` for perturbation `Transform to lowercase`	Fail rate: 0.000
# 2025-11-15 01:14:57,264 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:14:57,265 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:00.004347
# 2025-11-15 01:14:57,268 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:15:02,480 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:05.215119
# 2025-11-15 01:15:02,480 pid:91984 MainThread giskard.scanner.logger INFO     TextPerturbationDetector: Testing `text` for perturbation `Transform to title case`	Fail rate: 0.000
# 2025-11-15 01:15:03,024 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:15:03,025 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:00.004479
# 2025-11-15 01:15:03,029 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:15:08,179 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:05.153408
# 2025-11-15 01:15:08,179 pid:91984 MainThread giskard.scanner.logger INFO     TextPerturbationDetector: Testing `text` for perturbation `Add typos`	Fail rate: 0.000
# 2025-11-15 01:15:21,450 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:15:21,452 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:00.004480
# 2025-11-15 01:15:21,455 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:15:26,623 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:05.168585
# 2025-11-15 01:15:26,624 pid:91984 MainThread giskard.scanner.logger INFO     TextPerturbationDetector: Testing `text` for perturbation `Transform numbers to words`	Fail rate: 0.000
# 2025-11-15 01:15:26,729 pid:91984 MainThread giskard.scanner.logger INFO     NumericalPerturbationDetector: Running with transformations=['Multiply by factor', 'Multiply by factor', 'Add Gaussian noise'] threshold=None output_sensitivity=None num_samples=None
# 2025-11-15 01:15:26,730 pid:91984 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: Running
# 2025-11-15 01:15:26,731 pid:91984 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: Calculating loss
# 2025-11-15 01:15:26,739 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:15:26,745 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (14982, 2) executed in 0:00:00.013770
# 2025-11-15 01:15:26,748 pid:91984 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: Loss calculated (took 0:00:00.016794)
# 2025-11-15 01:15:26,748 pid:91984 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: Finding data slices
# 2025-11-15 01:15:56,316 pid:91984 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: 6 slices found (took 0:00:29.561752)
# 2025-11-15 01:15:56,317 pid:91984 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: Analyzing issues
# 2025-11-15 01:15:56,331 pid:91984 MainThread giskard.datasets.base INFO     Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# 2025-11-15 01:15:56,332 pid:91984 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: Using overconfidence threshold = 0.5
# 2025-11-15 01:16:09,167 pid:91984 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: 0 issues found (took 0:00:12.849008)
# 2025-11-15 01:16:09,167 pid:91984 MainThread giskard.scanner.logger INFO     UnderconfidenceDetector: Running
# 2025-11-15 01:16:09,168 pid:91984 MainThread giskard.scanner.logger INFO     UnderconfidenceDetector: Calculating loss
# 2025-11-15 01:16:09,177 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:16:09,182 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (14982, 2) executed in 0:00:00.014582
# 2025-11-15 01:16:09,184 pid:91984 MainThread giskard.scanner.logger INFO     UnderconfidenceDetector: Loss calculated (took 0:00:00.015635)
# 2025-11-15 01:16:09,184 pid:91984 MainThread giskard.scanner.logger INFO     UnderconfidenceDetector: Finding data slices
# 2025-11-15 01:17:18,866 pid:91984 MainThread giskard.scanner.logger INFO     UnderconfidenceDetector: 25 slices found (took 0:01:09.680221)
# 2025-11-15 01:17:18,866 pid:91984 MainThread giskard.scanner.logger INFO     UnderconfidenceDetector: Analyzing issues
# 2025-11-15 01:17:18,878 pid:91984 MainThread giskard.datasets.base INFO     Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# 2025-11-15 01:17:32,273 pid:91984 MainThread giskard.scanner.logger INFO     UnderconfidenceDetector: 0 issues found (took 0:00:13.406593)
# 2025-11-15 01:17:32,274 pid:91984 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: Running
# 2025-11-15 01:17:32,284 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:17:32,290 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (14982, 2) executed in 0:00:00.014798
# 2025-11-15 01:17:44,996 pid:91984 MainThread giskard.datasets.base INFO     Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# 2025-11-15 01:17:45,199 pid:91984 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `charset(text)` == "ascii"	Association = nan
# 2025-11-15 01:17:46,869 pid:91984 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "bathroom"	Association = nan
# 2025-11-15 01:17:47,892 pid:91984 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "location"	Association = nan
# 2025-11-15 01:17:48,107 pid:91984 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "rooms"	Association = nan
# 2025-11-15 01:17:49,562 pid:91984 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "hotel"	Association = nan
# 2025-11-15 01:17:50,179 pid:91984 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "excellent"	Association = nan
# 2025-11-15 01:17:50,456 pid:91984 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "small"	Association = nan
# 2025-11-15 01:17:55,280 pid:91984 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "bed"	Association = nan
# 2025-11-15 01:17:55,367 pid:91984 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "great"	Association = nan
# 2025-11-15 01:17:56,579 pid:91984 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "service"	Association = nan
# 2025-11-15 01:18:01,380 pid:91984 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "comfortable"	Association = nan
# 2025-11-15 01:18:03,043 pid:91984 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "helpful"	Association = nan
# 2025-11-15 01:18:03,668 pid:91984 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "nice"	Association = nan
# 2025-11-15 01:18:04,076 pid:91984 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "friendly"	Association = nan
# 2025-11-15 01:18:04,580 pid:91984 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "stay"	Association = nan
# 2025-11-15 01:18:05,874 pid:91984 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "clean"	Association = nan
# 2025-11-15 01:18:06,034 pid:91984 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "room"	Association = nan
# 2025-11-15 01:18:07,534 pid:91984 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "good"	Association = nan
# 2025-11-15 01:18:07,879 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Running
# 2025-11-15 01:18:07,879 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Calculating loss
# 2025-11-15 01:18:07,895 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:18:07,901 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (14982, 2) executed in 0:00:00.021484
# 2025-11-15 01:18:11,883 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Loss calculated (took 0:00:04.004004)
# 2025-11-15 01:18:11,884 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Finding data slices
# 2025-11-15 01:19:08,219 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: 19 slices found (took 0:00:56.333948)
# 2025-11-15 01:19:08,219 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Analyzing issues
# 2025-11-15 01:19:08,228 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:19:08,233 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (14982, 2) executed in 0:00:00.013288
# 2025-11-15 01:19:08,233 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing 19 slices for performance issues.
# 2025-11-15 01:19:08,264 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "bathroom"	Precision = 0.424 (global 0.551) Δm = -0.230	is_issue = True
# 2025-11-15 01:19:08,318 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "helpful"	Precision = 0.935 (global 0.551) Δm = 0.698	is_issue = False
# 2025-11-15 01:19:08,341 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "friendly"	Precision = 0.933 (global 0.551) Δm = 0.694	is_issue = False
# 2025-11-15 01:19:08,367 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "stay"	Precision = 0.642 (global 0.551) Δm = 0.166	is_issue = False
# 2025-11-15 01:19:08,387 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "room"	Precision = 0.491 (global 0.551) Δm = -0.107	is_issue = True
# 2025-11-15 01:19:08,431 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "hotel"	Precision = 0.640 (global 0.551) Δm = 0.162	is_issue = False
# 2025-11-15 01:19:08,454 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "excellent"	Precision = 0.946 (global 0.551) Δm = 0.719	is_issue = False
# 2025-11-15 01:19:08,477 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "bed"	Precision = 0.630 (global 0.551) Δm = 0.144	is_issue = False
# ...
# 2025-11-15 01:19:08,771 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "nice"	Precision = 0.857 (global 0.551) Δm = 0.557	is_issue = False
# 2025-11-15 01:19:08,802 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "bathroom"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-15 01:19:08,828 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "helpful"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-15 01:19:08,851 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "friendly"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-15 01:19:08,878 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "stay"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-15 01:19:08,897 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "room"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-15 01:19:08,922 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "hotel"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-15 01:19:08,945 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "excellent"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-15 01:19:08,968 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "bed"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-15 01:19:08,991 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "great"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-15 01:19:09,016 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "clean"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-15 01:19:09,039 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "rooms"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-15 01:19:09,063 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "good"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-15 01:19:09,088 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "location"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-15 01:19:09,113 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "staff"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-15 01:19:09,141 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "small"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-15 01:19:09,168 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "service"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-15 01:19:09,192 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "breakfast"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-15 01:19:09,215 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "comfortable"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-15 01:19:09,239 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "nice"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-15 01:19:09,266 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "bathroom"	Accuracy = 0.424 (global 0.551) Δm = -0.230	is_issue = True
# 2025-11-15 01:19:09,324 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "helpful"	Accuracy = 0.935 (global 0.551) Δm = 0.698	is_issue = False
# 2025-11-15 01:19:09,347 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "friendly"	Accuracy = 0.933 (global 0.551) Δm = 0.694	is_issue = False
# 2025-11-15 01:19:09,377 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "stay"	Accuracy = 0.642 (global 0.551) Δm = 0.166	is_issue = False
# 2025-11-15 01:19:09,397 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "room"	Accuracy = 0.491 (global 0.551) Δm = -0.107	is_issue = True
# 2025-11-15 01:19:09,448 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "hotel"	Accuracy = 0.640 (global 0.551) Δm = 0.162	is_issue = False
# 2025-11-15 01:19:09,471 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "excellent"	Accuracy = 0.946 (global 0.551) Δm = 0.719	is_issue = False
# 2025-11-15 01:19:09,498 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "bed"	Accuracy = 0.630 (global 0.551) Δm = 0.144	is_issue = False
# 2025-11-15 01:19:09,521 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "great"	Accuracy = 0.899 (global 0.551) Δm = 0.634	is_issue = False
# 2025-11-15 01:19:09,543 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "clean"	Accuracy = 0.878 (global 0.551) Δm = 0.595	is_issue = False
# 2025-11-15 01:19:09,566 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "rooms"	Accuracy = 0.541 (global 0.551) Δm = -0.016	is_issue = False
# 2025-11-15 01:19:09,592 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "good"	Accuracy = 0.822 (global 0.551) Δm = 0.494	is_issue = False
# 2025-11-15 01:19:09,616 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "location"	Accuracy = 0.924 (global 0.551) Δm = 0.679	is_issue = False
# 2025-11-15 01:19:09,640 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "staff"	Accuracy = 0.837 (global 0.551) Δm = 0.521	is_issue = False
# 2025-11-15 01:19:09,666 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "small"	Accuracy = 0.208 (global 0.551) Δm = -0.622	is_issue = True
# 2025-11-15 01:19:09,719 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "service"	Accuracy = 0.549 (global 0.551) Δm = -0.002	is_issue = False
# 2025-11-15 01:19:09,740 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "breakfast"	Accuracy = 0.618 (global 0.551) Δm = 0.122	is_issue = False
# 2025-11-15 01:19:09,762 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "comfortable"	Accuracy = 0.904 (global 0.551) Δm = 0.643	is_issue = False
# 2025-11-15 01:19:09,788 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "nice"	Accuracy = 0.857 (global 0.551) Δm = 0.557	is_issue = False
# 2025-11-15 01:19:09,788 pid:91984 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: 3 issues found (took 0:00:01.569012)
# 2025-11-15 01:19:09,789 pid:91984 MainThread giskard.scanner.logger INFO     StochasticityDetector: Running
# 2025-11-15 01:19:09,791 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:19:10,387 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (100, 2) executed in 0:00:00.596090
# 2025-11-15 01:19:10,388 pid:91984 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-15 01:19:10,911 pid:91984 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (100, 2) executed in 0:00:00.524008
# <iframe id="scan-23214547984" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#
# &lt;head&gt;
#     &lt;title&gt;Giskard Scan Results&lt;/title&gt;
#     &lt;base target=&quot;_blank&quot;&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#
# &lt;style&gt;pre code.hljs{display:block;overflow-x:auto;padding:1em}code.hljs{padding:3px 5px}
# /*!
#   Theme: GitHub Dark
#   Description: Dark theme as seen on github.com
#   Author: github.com
#   Maintainer: @Hirse
#   Updated: 2021-05-15
#
#   Outdated base version: https://github.com/primer/github-syntax-dark
#   Current colors taken from GitHub&#x27;s CSS
# */.hljs{background:#0d1117;color:#c9d1d9}.hljs-doctag,.hljs-keyword,.hljs-meta .hljs-keyword,.hljs-template-tag,.hljs-template-variable,.hljs-type,.hljs-variable.language_{color:#ff7b72}.hljs-title,.hljs-title.class_,.hljs-title.class_.inherited__,.hljs-title.function_{color:#d2a8ff}.hljs-attr,.hljs-attribute,.hljs-literal,.hljs-meta,.hljs-number,.hljs-operator,.hljs-selector-attr,.hljs-selector-class,.hljs-selector-id,.hljs-variable{color:#79c0ff}.hljs-meta .hljs-string,.hljs-regexp,.hljs-string{color:#a5d6ff}.hljs-built_in,.hljs-symbol{color:#ffa657}.hljs-code,.hljs-comment,.hljs-formula{color:#8b949e}.hljs-name,.hljs-quote,.hljs-selector-pseudo,.hljs-selector-tag{color:#7ee787}.hljs-subst{color:#c9d1d9}.hljs-section{color:#1f6feb;font-weight:700}.hljs-bullet{color:#f2cc60}.hljs-emphasis{color:#c9d1d9;font-style:italic}.hljs-strong{color:#c9d1d9;font-weight:700}.hljs-addition{background-color:#033a16;color:#aff5b4}.hljs-deletion{background-color:#67060c;color:#ffdcd7}.hljs-copy-wrapper{overflow:hidden;position:relative}.hljs-copy-button:focus,.hljs-copy-wrapper:hover .hljs-copy-button{transform:translateX(0)}.hljs-copy-button{background-color:#2d2b57;background-color:var(--hljs-theme-background);background-image:url(&#x27;data:image/svg+xml;charset=utf-8,&lt;svg xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;16&quot; height=&quot;16&quot; fill=&quot;none&quot; viewBox=&quot;0 0 24 24&quot;&gt;&lt;path fill=&quot;%23fff&quot; fill-rule=&quot;evenodd&quot; d=&quot;M6 5a1 1 0 0 0-1 1v14a1 1 0 0 0 1 1h12a1 1 0 0 0 1-1V6a1 1 0 0 0-1-1h-2a1 1 0 1 1 0-2h2a3 3 0 0 1 3 3v14a3 3 0 0 1-3 3H6a3 3 0 0 1-3-3V6a3 3 0 0 1 3-3h2a1 1 0 0 1 0 2H6Z&quot; clip-rule=&quot;evenodd&quot;/&gt;&lt;path fill=&quot;%23fff&quot; fill-rule=&quot;evenodd&quot; d=&quot;M7 3a2 2 0 0 1 2-2h6a2 2 0 0 1 2 2v2a2 2 0 0 1-2 2H9a2 2 0 0 1-2-2V3Zm8 0H9v2h6V3Z&quot; clip-rule=&quot;evenodd&quot;/&gt;&lt;/svg&gt;&#x27;);background-position:50%;background-repeat:no-repeat;border:1px solid #ffffff22;border-radius:.25rem;color:#fff;height:2rem;position:absolute;right:1em;text-indent:-9999px;top:1em;transition:background-color .2s ease,transform .2s ease-out;width:2rem}.hljs-copy-button:hover{border-color:#ffffff44}.hljs-copy-button:active{border-color:#ffffff66}.hljs-copy-button[data-copied=true]{background-image:none;text-indent:0;width:auto}@media (prefers-reduced-motion){.hljs-copy-button{transition:none}}.hljs-copy-alert{clip:rect(0 0 0 0);-webkit-clip-path:inset(50%);clip-path:inset(50%);height:1px;overflow:hidden;position:absolute;white-space:nowrap;width:1px}
# /*! tailwindcss v3.3.2 | MIT License | https://tailwindcss.com*/*,:after,:before{border:0 solid #e5e7eb;box-sizing:border-box}:after,:before{--tw-content:&quot;&quot;}html{-webkit-text-size-adjust:100%;font-feature-settings:normal;font-family:ui-sans-serif,system-ui,-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,Noto Color Emoji;font-variation-settings:normal;line-height:1.5;-moz-tab-size:4;-o-tab-size:4;tab-size:4}body{line-height:inherit;margin:0}hr{border-top-width:1px;color:inherit;height:0}abbr:where([title]){-webkit-text-decoration:underline dotted;text-decoration:underline dotted}h1,h2,h3,h4,h5,h6{font-size:inherit;font-weight:inherit}a{color:inherit;text-decoration:inherit}b,strong{font-weight:bolder}code,kbd,pre,samp{font-family:ui-monospace,SFMono-Regular,Menlo,Monaco,Consolas,Liberation Mono,Courier New,monospace;font-size:1em}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sub{bottom:-.25em}sup{top:-.5em}table{border-collapse:collapse;border-color:inherit;text-indent:0}button,input,optgroup,select,textarea{color:inherit;font-family:inherit;font-size:100%;font-weight:inherit;line-height:inherit;margin:0;padding:0}button,select{text-transform:none}[type=button],[type=reset],[type=submit],button{-webkit-appearance:button;background-color:transparent;background-image:none}:-moz-focusring{outline:auto}:-moz-ui-invalid{box-shadow:none}progress{vertical-align:baseline}::-webkit-inner-spin-button,::-webkit-outer-spin-button{height:auto}[type=search]{-webkit-appearance:textfield;outline-offset:-2px}::-webkit-search-decoration{-webkit-appearance:none}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}summary{display:list-item}blockquote,dd,dl,figure,h1,h2,h3,h4,h5,h6,hr,p,pre{margin:0}fieldset{margin:0}fieldset,legend{padding:0}menu,ol,ul{list-style:none;margin:0;padding:0}textarea{resize:vertical}input::-moz-placeholder,textarea::-moz-placeholder{color:#9ca3af;opacity:1}input::placeholder,textarea::placeholder{color:#9ca3af;opacity:1}[role=button],button{cursor:pointer}:disabled{cursor:default}audio,canvas,embed,iframe,img,object,svg,video{display:block;vertical-align:middle}img,video{height:auto;max-width:100%}[hidden]{display:none}*,:after,:before{--tw-border-spacing-x:0;--tw-border-spacing-y:0;--tw-translate-x:0;--tw-translate-y:0;--tw-rotate:0;--tw-skew-x:0;--tw-skew-y:0;--tw-scale-x:1;--tw-scale-y:1;--tw-pan-x: ;--tw-pan-y: ;--tw-pinch-zoom: ;--tw-scroll-snap-strictness:proximity;--tw-gradient-from-position: ;--tw-gradient-via-position: ;--tw-gradient-to-position: ;--tw-ordinal: ;--tw-slashed-zero: ;--tw-numeric-figure: ;--tw-numeric-spacing: ;--tw-numeric-fraction: ;--tw-ring-inset: ;--tw-ring-offset-width:0px;--tw-ring-offset-color:#fff;--tw-ring-color:rgba(59,130,246,.5);--tw-ring-offset-shadow:0 0 #0000;--tw-ring-shadow:0 0 #0000;--tw-shadow:0 0 #0000;--tw-shadow-colored:0 0 #0000;--tw-blur: ;--tw-brightness: ;--tw-contrast: ;--tw-grayscale: ;--tw-hue-rotate: ;--tw-invert: ;--tw-saturate: ;--tw-sepia: ;--tw-drop-shadow: ;--tw-backdrop-blur: ;--tw-backdrop-brightness: ;--tw-backdrop-contrast: ;--tw-backdrop-grayscale: ;--tw-backdrop-hue-rotate: ;--tw-backdrop-invert: ;--tw-backdrop-opacity: ;--tw-backdrop-saturate: ;--tw-backdrop-sepia: }::backdrop{--tw-border-spacing-x:0;--tw-border-spacing-y:0;--tw-translate-x:0;--tw-translate-y:0;--tw-rotate:0;--tw-skew-x:0;--tw-skew-y:0;--tw-scale-x:1;--tw-scale-y:1;--tw-pan-x: ;--tw-pan-y: ;--tw-pinch-zoom: ;--tw-scroll-snap-strictness:proximity;--tw-gradient-from-position: ;--tw-gradient-via-position: ;--tw-gradient-to-position: ;--tw-ordinal: ;--tw-slashed-zero: ;--tw-numeric-figure: ;--tw-numeric-spacing: ;--tw-numeric-fraction: ;--tw-ring-inset: ;--tw-ring-offset-width:0px;--tw-ring-offset-color:#fff;--tw-ring-color:rgba(59,130,246,.5);--tw-ring-offset-shadow:0 0 #0000;--tw-ring-shadow:0 0 #0000;--tw-shadow:0 0 #0000 ...

# %% [markdown]
# We have only a few issues. Perfect. We have performance problems in some segments, containing words like "small" or "bathroom". Fixing such issues is often not straightforward, however, and generally requires more data, or data augmentation with e.g. [nlpaug](https://github.com/makcedward/nlpaug) library. Typically, fixing many of these issues is quite hard, but just being aware of them can be useful.

# %% [markdown]
# # Interpretability
# Interpretability is a fundamental aspect of developing trustworthy and effective AI systems, particularly when decisions made by these systems have significant implications. It involves understanding and explaining how AI models make their decisions, which is crucial for gaining user trust, fulfilling regulatory requirements, and facilitating model debugging and improvement. It bridges the gap between advanced computational models and human understanding, ensuring that AI systems are not only powerful and efficient but also aligned with ethical standards and user expectations.

# %% [markdown]
# ## Global vs local explainability
#
# Understanding the overall behavior of the model is known as **global explainability**, and is generally tough. Modern NLP models are incredibly complex and basically impossible to summarize like "if description mentions small room, then predict negative sentiment". This is also less interesting to end users, who are often interested in understanding prediction for a single given text, known as **local interpretability**.
#
# There are a lot of techniques for this, benchmarked in papers:
# - ["A Diagnostic Study of Explainability Techniques for Text Classification" P. Atanasova et al.](https://aclanthology.org/2020.emnlp-main.263/)
# - ["A Multilingual Perspective Towards the Evaluation of Attribution Methods in Natural Language Inference" K. Zaman, Y. Belinkov](https://aclanthology.org/2022.emnlp-main.101/)
#
# Interestingly, both papers and our practical experience show that the simplest **gradient attribution** methods perform the best. They are fast, faithful to the inner workings of the model, and make sense for human evaluators. Concretely, InputXGradient method with either mean or L2 normalization per word gives the best results. In short, it works as follows:
# 1. Compute model prediction with gradients, just like during training, but without updating model weights.
# 2. With backpropagation, compute gradient for each input token, also known as saliency or **attribution**.
# 3. Multiply tokens by their gradient (hence the name), getting token attribution vector.
# 4. Normalize attribution, i.e., calculate either average or L2-normalized score for each word.
#
# This way, we get a single number per token. Gradients are computed for a given class. For binary classification, we predict the probability of positive class. Therefore, higher scores indicate that tokens increase the probability, and negative scores mean that they decrease probability.
#
# Why does this simple method work very well? We don't really know. There are some hypotheses, but they are of high mathematical complexity. If you're interested, see e.g. ["The Manifold Hypothesis for Gradient-Based Explanations" S. Bordt et al](https://openaccess.thecvf.com/content/CVPR2023W/XAI4CV/papers/Bordt_The_Manifold_Hypothesis_for_Gradient-Based_Explanations_CVPRW_2023_paper.pdf). A major advantage is also speed. This requires computing gradients, but it's still just one forward and backward pass through the model. Other methods are much more complex, like SHAP for text, which has almost exponential complexity.

# %% [markdown]
# ## Local explainability with Captum
#
# [Captum](https://captum.ai/) is the most popular model interpretability library for PyTorch. It works for computer vision, NLP, [LLMs](https://captum.ai/tutorials/Llama2_LLM_Attribution) and other models. While the most important part are model attributions, which we will use to understand inputs, Captum also supports adversarial attacks, neuron and layer explanations, and identifying influential examples.
#
# The code below is modified from [Captum question answering tutorial](https://captum.ai/tutorials/Bert_SQUAD_Interpret). Firstly, we tokenize texts. The essential part is calling the `configure_interpretable_embedding_layer()` function - this special embedding layer replaces the existing transformer embedding layer with Captum one, which tracks gradients and combines explanations with original tokens. Furthermore, since Captum requires gradients, we need to make a small wrapper to pass `attention_mask` to our transformer. Lastly, we make the overall model prediction and use built-in visualization methods to plot the results.

# %%
from copy import deepcopy

from captum.attr import InputXGradient, configure_interpretable_embedding_layer
from captum.attr import visualization as vis


class BERTModelWrapper(torch.nn.Module):
    def __init__(self, model):
        super().__init__()
        self.model = model

    def forward(self, inputs, attention_mask):
        return self.model(inputs, attention_mask=attention_mask)[0]


def explain_text(model, text: str, y_true: int) -> None:
    # make sure we compute gradients as necessary
    for param in model.distilbert.parameters():
        param.requires_grad = True
    
    tokenizer_output = tokenizer.encode_plus(
        text,
        add_special_tokens=True,
        return_attention_mask=True,
        return_tensors="pt",
    )
    
    device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
    tokenizer_output = tokenizer_output.to(device)
    tokens = tokenizer.convert_ids_to_tokens(tokenizer_output["input_ids"][0])

    model_copy = deepcopy(model)
    interpretable_embedding_layer = configure_interpretable_embedding_layer(
        model_copy, "distilbert.embeddings"
    )

    input_embeddings = interpretable_embedding_layer.indices_to_embeddings(
        tokenizer_output["input_ids"]
    )

    model_wrapper = BERTModelWrapper(model_copy)
    input_x_gradient = InputXGradient(model_wrapper)
    attributions = input_x_gradient.attribute(
        input_embeddings,
        target=1,
        additional_forward_args=tokenizer_output["attention_mask"],
    )

    # mean normalization
    attributions = attributions.sum(dim=-1).squeeze(0)
    attributions = attributions / torch.norm(attributions)
    attributions = list([float(attr) for attr in attributions])
    
    with torch.no_grad():
        logits = model(**tokenizer_output).logits
        y_pred_proba = softmax(logits, dim=1)[0, 1].item()
        y_pred = int(y_pred_proba >= 0.5)

    # remove [CLS] and [SEP] tokens
    attributions = attributions[1:-1]
    tokens = tokens[1:-1]
    
    vis_record = vis.VisualizationDataRecord(
        word_attributions=attributions,
        pred_prob=y_pred_proba,
        pred_class=y_pred,
        true_class=y_true,
        attr_class=1,
        attr_score=sum(attributions),
        raw_input_ids=tokens,
        convergence_score=0,
    )
    vis.visualize_text([vis_record])

# %% [markdown]
# ### Exercise 5 (1 point)
#
# 1. Use Captum and implemented function to explain predictions for the first 3 positive and 3 negative samples from the test set.
# 2. Comment, do you think that results make sense? Does the model focus on reasonable words, both for positive and negative sentiment?

# %%
positive_samples = df_test[df_test["label"] == 1].head(3)

print(f"Positive samples\n")
for idx, row in positive_samples.iterrows():
    explain_text(trainer.model, row["text"], y_true=row["label"])



negative_samples = df_test[df_test["label"] == 0].head(3)

print(f"Negative samples\n")
for idx, row in negative_samples.iterrows():
    explain_text(trainer.model, row["text"], y_true=row["label"])
# Out:
# Positive samples
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>1 (0.98)</b></text></td><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>-0.72</b></text></td><td><mark style="background-color: hsl(0, 75%, 90%); opacity:1.0;                     line-height:1.75"><font color="black"> very                    </font></mark><mark style="background-color: hsl(0, 75%, 88%); opacity:1.0;                     line-height:1.75"><font color="black"> contemporary                    </font></mark><mark style="background-color: hsl(120, 75%, 79%); opacity:1.0;                     line-height:1.75"><font color="black"> decor                    </font></mark><mark style="background-color: hsl(120, 75%, 86%); opacity:1.0;                     line-height:1.75"><font color="black"> nice                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> view                    </font></mark><mark style="background-color: hsl(0, 75%, 92%); opacity:1.0;                     line-height:1.75"><font color="black"> from                    </font></mark><mark style="background-color: hsl(0, 75%, 85%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(0, 75%, 89%); opacity:1.0;                     line-height:1.75"><font color="black"> 9th                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> floor                    </font></mark></td><tr></table>
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>1 (1.00)</b></text></td><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>1.19</b></text></td><td><mark style="background-color: hsl(0, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> a                    </font></mark><mark style="background-color: hsl(0, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> very                    </font></mark><mark style="background-color: hsl(120, 75%, 82%); opacity:1.0;                     line-height:1.75"><font color="black"> nice                    </font></mark><mark style="background-color: hsl(120, 75%, 89%); opacity:1.0;                     line-height:1.75"><font color="black"> break                    </font></mark><mark style="background-color: hsl(120, 75%, 78%); opacity:1.0;                     line-height:1.75"><font color="black"> fast                    </font></mark><mark style="background-color: hsl(0, 75%, 86%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> room                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> was                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> very                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> cozy                    </font></mark><mark style="background-color: hsl(120, 75%, 69%); opacity:1.0;                     line-height:1.75"><font color="black"> and                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> clean                    </font></mark></td><tr></table>
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>1 (0.96)</b></text></td><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>-0.80</b></text></td><td><mark style="background-color: hsl(0, 75%, 87%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(0, 75%, 89%); opacity:1.0;                     line-height:1.75"><font color="black"> staff                    </font></mark><mark style="background-color: hsl(120, 75%, 84%); opacity:1.0;                     line-height:1.75"><font color="black"> specially                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> diana                    </font></mark><mark style="background-color: hsl(120, 75%, 89%); opacity:1.0;                     line-height:1.75"><font color="black"> is                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> super                    </font></mark><mark style="background-color: hsl(0, 75%, 80%); opacity:1.0;                     line-height:1.75"><font color="black"> they                    </font></mark><mark style="background-color: hsl(120, 75%, 87%); opacity:1.0;                     line-height:1.75"><font color="black"> work                    </font></mark><mark style="background-color: hsl(0, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> really                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> nice                    </font></mark><mark style="background-color: hsl(0, 75%, 89%); opacity:1.0;                     line-height:1.75"><font color="black"> they                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> try                    </font></mark><mark style="background-color: hsl(0, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> to                    </font></mark><mark style="background-color: hsl(120, 75%, 89%); opacity:1.0;                     line-height:1.75"><font color="black"> keep                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> guest                    </font></mark><mark style="background-color: hsl(120, 75%, 90%); opacity:1.0;                     line-height:1.75"><font color="black"> happy                    </font></mark></td><tr></table>
# Negative samples
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>0</b></text></td><td><text style="padding-right:2em"><b>0 (0.14)</b></text></td><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>1.19</b></text></td><td><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(120, 75%, 84%); opacity:1.0;                     line-height:1.75"><font color="black"> breakfast                    </font></mark><mark style="background-color: hsl(120, 75%, 88%); opacity:1.0;                     line-height:1.75"><font color="black"> was                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> over                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> ##pr                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ice                    </font></mark><mark style="background-color: hsl(120, 75%, 78%); opacity:1.0;                     line-height:1.75"><font color="black"> ##d                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> so                    </font></mark><mark style="background-color: hsl(120, 75%, 87%); opacity:1.0;                     line-height:1.75"><font color="black"> we                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> tended                    </font></mark><mark style="background-color: hsl(0, 75%, 82%); opacity:1.0;                     line-height:1.75"><font color="black"> to                    </font></mark><mark style="background-color: hsl(0, 75%, 89%); opacity:1.0;                     line-height:1.75"><font color="black"> use                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> wet                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##hers                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##poo                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ns                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> pub                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><f ...
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>0</b></text></td><td><text style="padding-right:2em"><b>0 (0.08)</b></text></td><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>-0.49</b></text></td><td><mark style="background-color: hsl(0, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> 1                    </font></mark><mark style="background-color: hsl(120, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> they                    </font></mark><mark style="background-color: hsl(120, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> didn                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> t                    </font></mark><mark style="background-color: hsl(0, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> proved                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(0, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> gust                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> card                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> to                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> enter                    </font></mark><mark style="background-color: hsl(0, 75%, 90%); opacity:1.0;                     line-height:1.75"><font color="black"> all                    </font></mark><mark style="background-color: hsl(120, 75%, 89%); opacity:1.0;                     line-height:1.75"><font color="black"> attraction                    </font></mark><mark style="background-color: hsl(0, 75%, 92%); opacity:1.0;                     line-height:1.75"><font color="black"> 2                    </font></mark><mark style="background-color: hsl(120, 75%, 82%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> breakfast                    </font></mark><mark style="background-color: hsl(0, 75%, 84%); opacity:1.0;                     line-height:1.75"><font color="black"> was                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> little                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> bet                    </font></mark><mark style="background-color: hsl(0, 75%, 84%); opacity:1.0;                     line-height:1.75"><f ...
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>0</b></text></td><td><text style="padding-right:2em"><b>0 (0.02)</b></text></td><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>0.14</b></text></td><td><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> du                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> ##vet                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> was                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> a                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> it                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> ##chy                    </font></mark><mark style="background-color: hsl(0, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> blanket                    </font></mark><mark style="background-color: hsl(0, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> in                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> between                    </font></mark><mark style="background-color: hsl(120, 75%, 91%); opacity:1.0;                     line-height:1.75"><font color="black"> two                    </font></mark><mark style="background-color: hsl(120, 75%, 91%); opacity:1.0;                     line-height:1.75"><font color="black"> sheets                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> really                    </font></mark><mark style="background-color: hsl(0, 75%, 84%); opacity:1.0;                     line-height:1.75"><font color="black"> un                    </font></mark><mark style="background-color: hsl(120, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> comfortable                    </font></mark><mark style="background-color: hsl(120, 75%, 83%); opacity:1.0;                     line-height:1.75"><font color="black"> shower                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> dr                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ib                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> ##bled                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-hei ...

# %% [markdown]
# Well it obviously makes sense that it highlights words like nice or happy as having positive impact for the prediction (or rather pushing the probability more towards 1), as well as it makes sense to highlight words like poor as having negative impact. Obviosuly for cases like money it can be used both depending wheter is overpriced or not and this cannot be determined by looking at a single word.
