# %% [markdown]
# # Laboratory 5 instruction part 2 - MLflow
#
# In machine learning development, one of the most challenging aspects is maintaining reproducibility. This issue is particularly relevant to the experimental phase, when a lot of small, but influential code changes are constantly introduced.
#
# After extensive experimentation with different model architectures, hyperparameters, and preprocessing techniques, researchers often find themselves unable to recreate their best-performing models because critical configuration details were not properly recorded.

# %% [markdown]
# ## MLflow
#
# [MLflow is an open-source platform](https://mlflow.org/) that addresses this challenge by providing systematic experiment tracking throughout the machine learning lifecycle. It automatically captures configurations, metrics, and artifacts from each model training run, transforming ad-hoc model development into a structured, reproducible process. In this notebook, we will learn how to use MLflow to properly track experiments for both traditional machine learning and deep learning workflows.

# %% [markdown]
# ### Learning objectives
#
# 1. **Implement automated experiment tracking** using MLflow autologging capabilities with scikit-learn, enabling automatic capture of model parameters and metrics without writing additional tracking code.
#
# 2. **Configure manual logging strategies** for PyTorch experiments, implementing custom tracking for metrics, parameters, and artifacts throughout the training process.
#
# 3. **Analyze and compare experimental results** using MLflow tracking UI and programmatic APIs to identify optimal model configurations and understand performance patterns.

# %% [markdown]
# ### Laboratory plan
#
# 1. **MLflow tracking server** configuration and deployment for experiment management
# 2. **Automatic logging mechanisms** for scikit-learn experiments
# 3. **Manual logging implementation** for PyTorch deep learning workflows
# 4. **Hyperparameter optimization exercise** - systematic hyperparameter exploration
# 5. **Best practices** for experiment organization, versioning, and cross-team reproducibility

# %% [markdown]
# ## 1. MLflow Tracking server configuration

# %% [markdown]
# [MLflow Tracking](https://mlflow.org/docs/latest/tracking/) is the main component of MLflow, responsible for capturing, storing, and presenting metrics, logs, and other tracking data. MLflow is based on a client-server architecture, where the central MLflow server can serve potentially whole teams of data scientists. You can also simply run it as a local server from the commandline, as we will now.

# %% [markdown]
# 1. Create a directory for MLflow artifacts storage:
# ```bash
# mkdir mlflow-artifacts
# ```
#
# 2. Start the MLflow tracking server:
# ```bash
# mlflow server \
#   --backend-store-uri sqlite:///mlflow.db \
#   --default-artifact-root ./mlflow-artifacts \
#   --host 0.0.0.0 \
#   --port 5000
# ```
# Important: Keep this terminal window open. The MLflow server will continue running and be accessible at http://localhost:5000

# %% [markdown]
# To verify if the server runs properly, let's connect to it:

# %%
import mlflow
import mlflow.sklearn

import warnings

warnings.filterwarnings("ignore")

mlflow.set_tracking_uri("http://localhost:5000")
print(f"Connected to MLflow at: {mlflow.get_tracking_uri()}")
# Out:
# Connected to MLflow at: http://localhost:5000

# %% [markdown]
# Setup complete! You now have the MLflow server running as a separate process, and `mlflow` library in this Jupyter Notebook is connected to it. Just note that we had to use the proper host and port - if you want to connect to a remote server, modify the tracking URI appropriately.

# %% [markdown]
# ## 2. Automatic logging with scikit-learn

# %% [markdown]
# ### 2.1 Dataset preparation
#
# In this section, we'll use the Ames Housing dataset to demonstrate MLflow's autologging capabilities with scikit-learn. Since we have already prepared the 2006-2008 data using DVC, we can use our preprocessed dataset here. As we have temporal data, the best way to evaluate our model is time (chronological) split, where the newest data is used for testing. We will assume that we have the data for years 2006 and 2007, and evaluate using data from 2008.

# %%
import numpy as np
import pandas as pd

from feature_engine.encoding import RareLabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# %%
df = pd.read_parquet("data/ames_data_2006_2008.parquet")

df = df.sort_values(by=["YrSold"])

df_train = df[df["YrSold"] < 2008]
df_test = df[df["YrSold"] == 2008]

y_train = df_train.pop("SalePrice")
y_test = df_test.pop("SalePrice")

categorical_features = df_train.select_dtypes(include="object").columns
numerical_features = df_train.select_dtypes(exclude="object").columns

# %%
median_imputer = SimpleImputer(strategy="median")
min_max_scaler = MinMaxScaler()
rare_encoder = RareLabelEncoder(tol=0.01, n_categories=0)
one_hot_encoder = OneHotEncoder(
    drop="first", sparse_output=False, handle_unknown="ignore"
)

num_pipeline = Pipeline(
    [("median_imputer", median_imputer), ("min_max_scaler", min_max_scaler)]
)

cat_pipeline = Pipeline(
    [("rare_encoder", rare_encoder), ("one_hot_encoder", one_hot_encoder)]
)

column_transformer = ColumnTransformer(
    [
        ("num_pipeline", num_pipeline, numerical_features),
        ("cat_pipeline", cat_pipeline, categorical_features),
    ],
    verbose_feature_names_out=False,
)
column_transformer.fit(df_train)

X_train = column_transformer.transform(df_train)
X_test = column_transformer.transform(df_test)

# %%
print(f"Training samples: {X_train.shape[0]}")
print(f"Test samples: {X_test.shape[0]}")
print(f"Number of features: {X_train.shape[1]}")
# Out:
# Training samples: 1312
# Test samples: 621
# Number of features: 181

# %% [markdown]
# ### 2.2 Training with MLflow autologging

# %% [markdown]
# Autologging is a powerful built-in capability of MLflow, enabling fully automated and near-zero code integration of MLflow with many popular frameworks. In particular, it works really well with scikit-learn, thanks to its highly unified API. Let's try this out - we will enable autologging, and then train a buch of different models.

# %%
mlflow.sklearn.autolog(
    log_input_examples=True, log_model_signatures=True, log_models=False, silent=False
)

mlflow.set_experiment("ames-housing-autolog")
# Out:
# 2025/11/09 20:36:04 WARNING mlflow.utils.autologging_utils: MLflow sklearn autologging is known to be compatible with 0.24.1 <= scikit-learn <= 1.6.1, but the installed version is 1.7.0. If you encounter errors during autologging, try upgrading / downgrading scikit-learn to a compatible version, or try upgrading MLflow.
# 2025/11/09 20:36:10 INFO mlflow.tracking.fluent: Experiment with name 'ames-housing-autolog' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/Users/mnozkiewicz/Magisterka/MLOPS/lab5/mlflow-artifacts/1', creation_time=1762716970818, experiment_id='1', last_update_time=1762716970818, lifecycle_stage='active', name='ames-housing-autolog', tags={}>

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor


models = [
    ("Ridge Regression", Ridge()),
    ("Decision Tree", DecisionTreeRegressor(max_depth=10, random_state=42)),
    ("K-Nearest Neighbors", KNeighborsRegressor(n_neighbors=10)),
    ("Random Forest", RandomForestRegressor(n_estimators=100, random_state=42)),
    ("Gradient Boosting", GradientBoostingRegressor(n_estimators=100, random_state=42)),
]

# %%
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score


def fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test):
    results = {}

    for model_name, model in models:
        # start MLflow run - a unit grouping logs from different model runs
        # everything within this context manager will get logged as a run
        with mlflow.start_run(run_name=model_name):
            model.fit(X_train, y_train)

            y_pred = model.predict(X_test)

            rmse = root_mean_squared_error(y_test, y_pred)
            mae = mean_absolute_error(y_test, y_pred)
            r2 = r2_score(y_test, y_pred)

            cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring="r2")
            cv_mean = cv_scores.mean()
            cv_std = cv_scores.std()
            
            # log additional custom metrics, in addition to autologging
            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)

            results[model_name] = {
                "rmse": rmse,
                "mae": mae,
                "r2": r2,
                "cv_r2_mean": cv_mean,
            }

            print(f"\n{model_name}:")
            print(f"  RMSE: {rmse:.2f}")
            print(f"  MAE: {mae:.2f}")
            print(f"  R^2: {r2:.3f}")
            print(f"  CV R^2 (mean ± std): {cv_mean:.3f} ± {cv_std:.3f}")

# %%
fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test)
# Out:
# 2025/11/09 20:39:55 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:39:55 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:39:55 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:39:55 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:39:55 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:39:55 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:39:55 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:39:55 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:39:55 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:39:55 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:39:55 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:39:55 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Ridge Regression:
#   RMSE: 23450.39
#   MAE: 16430.79
#   R^2: 0.904
#   CV R^2 (mean ± std): 0.895 ± 0.035
# 🏃 View run Ridge Regression at: http://localhost:5000/#/experiments/1/runs/66975eb14a1c4c04a1c10fe63909fb7a
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
#
# Decision Tree:
#   RMSE: 36860.51
#   MAE: 23270.66
#   R^2: 0.762
#   CV R^2 (mean ± std): 0.755 ± 0.057
# 🏃 View run Decision Tree at: http://localhost:5000/#/experiments/1/runs/926f32effec84e3c87de434ef21093b4
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/11/09 20:39:55 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:39:55 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:39:55 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:39:55 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:39:55 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:39:55 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:39:55 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# K-Nearest Neighbors:
#   RMSE: 38324.60
#   MAE: 26033.27
#   R^2: 0.743
#   CV R^2 (mean ± std): 0.691 ± 0.049
# 🏃 View run K-Nearest Neighbors at: http://localhost:5000/#/experiments/1/runs/84413df8088744eabb75ff65aca0d601
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/11/09 20:39:56 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:39:57 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:39:58 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:39:59 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:40:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:40:01 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Random Forest:
#   RMSE: 25814.13
#   MAE: 15606.16
#   R^2: 0.883
#   CV R^2 (mean ± std): 0.879 ± 0.049
# 🏃 View run Random Forest at: http://localhost:5000/#/experiments/1/runs/334c1dc437074c47bfa1b011c6b2c529
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/11/09 20:40:01 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:40:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:40:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:40:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 20:40:03 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Gradient Boosting:
#   RMSE: 21600.50
#   MAE: 13840.01
#   R^2: 0.918
#   CV R^2 (mean ± std): 0.904 ± 0.031
# 🏃 View run Gradient Boosting at: http://localhost:5000/#/experiments/1/runs/9e40cb1958b4495c87819053810f7f64
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %% [markdown]
# Open the MLflow dashboard at http://localhost:5000/ and go to the Experiments tab. On the left, you have the experiment name, and when you select it, the list of all experiments will show up. Click through the interface and familiarize yourself with the most important elements:
#
# 1. What columns can be selected
# 2. Pick a particular run and check what values are logged automatically
# 3. Select columns to compare a given metric between runs, e.g. MAE
# 4. Sort algorithms by the selected metric to pick the best one

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# We have trained 5 different models. The results of all of them can now be compared in MLflow. Since we obtained quite satisfactory results, our imaginary client would like to be sure that we do our best and wants us to compare many more combinations.
#
# Your task is to run 5 more experiments with different parameters and models from scikit-learn. You can use any [supervised learning methods from scikit-learn](https://scikit-learn.org/stable/supervised_learning.html). Find some other models or parameters to tune our current models with and run the experiments again. Use the function `fit_sklearn_models_with_cv()` created above, or you can write your own if you want.
#
# Did you manage to beat the previous approaches?

# %%
from sklearn.svm import SVR
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import AdaBoostRegressor
from sklearn.gaussian_process import GaussianProcessRegressor

additional_models = [
    ("ElasticNet", ElasticNet(alpha=0.1, l1_ratio=0.5, random_state=42)), # additional regularization for linear model
    ("Random Forest", RandomForestRegressor(n_estimators=500, random_state=42)), # More trees for random forest
    ("Support Vector", SVR(kernel='rbf', C=1.0, epsilon=0.1)), # Support vectors
    ("AdaBoostr", AdaBoostRegressor(n_estimators=500, random_state=42)), # Ada boost
    ("Gaussian Process", GaussianProcessRegressor(random_state=42))
]

# %%
fit_sklearn_models_with_cv(additional_models, X_train, X_test, y_train, y_test)
# Out:
# 2025/11/09 21:02:56 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:02:56 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:02:56 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:02:56 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:02:56 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:02:56 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:02:56 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# ElasticNet:
#   RMSE: 27319.47
#   MAE: 18594.52
#   R^2: 0.869
#   CV R^2 (mean ± std): 0.843 ± 0.027
# 🏃 View run ElasticNet at: http://localhost:5000/#/experiments/1/runs/3324acf993f54c488ca72cddfb82f510
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/11/09 21:03:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:03:06 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:03:11 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:03:15 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:03:20 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:03:25 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Random Forest:
#   RMSE: 25750.77
#   MAE: 15460.94
#   R^2: 0.884
#   CV R^2 (mean ± std): 0.881 ± 0.047
# 🏃 View run Random Forest at: http://localhost:5000/#/experiments/1/runs/8d75e1c56895436c864c3ceb0d4b3b4c
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/11/09 21:03:25 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:03:25 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:03:25 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:03:26 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:03:26 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:03:26 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Support Vector:
#   RMSE: 77482.01
#   MAE: 54914.40
#   R^2: -0.051
#   CV R^2 (mean ± std): -0.103 ± 0.070
# 🏃 View run Support Vector at: http://localhost:5000/#/experiments/1/runs/90846c29bdcd4faf8501bf1c79fcbd2f
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/11/09 21:03:28 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:03:29 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:03:31 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:03:32 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:03:34 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:03:35 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# AdaBoostr:
#   RMSE: 32104.36
#   MAE: 23097.82
#   R^2: 0.820
#   CV R^2 (mean ± std): 0.830 ± 0.062
# 🏃 View run AdaBoostr at: http://localhost:5000/#/experiments/1/runs/9e278cd099bc41cc94b6d9aa3c3c9b2e
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/11/09 21:03:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:03:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:03:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:03:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 21:03:37 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Gaussian Process:
#   RMSE: 162799.40
#   MAE: 148233.18
#   R^2: -3.639
#   CV R^2 (mean ± std): -3.122 ± 0.888
# 🏃 View run Gaussian Process at: http://localhost:5000/#/experiments/1/runs/7f4ecead80474f89a1364c66bfd685b2
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %% [markdown]
# ![image.png](attachment:image.png)
#
# It seems like gradient boosting still won at the end.

# %% [markdown]
# ## 3. Manual logging with PyTorch

# %% [markdown]
# In this section, we'll implement manual logging for PyTorch models. While scikit-learn has autologging, PyTorch requires manual tracking - giving us full control over what and when to log. MLflow supports autologging for [PyTorch Lightning](https://lightning.ai/docs/pytorch/stable/), but many people prefer or often need low-level control of pure PyTorch. Thus, we will focus on this approach, which also will teach us more about powerful MLflow capabilities.
#
# Note that we need to turn off scikit-learn autologging! Since we are using a Jupyter Notebook, MLflow uses the previously configured autologging unless explicitly turned off.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import KFold

# disable sklearn autologging!
mlflow.sklearn.autolog(disable=True)

mlflow.set_experiment("pytorch-housing-manual-2")
# Out:
# 2025/11/09 22:03:33 INFO mlflow.tracking.fluent: Experiment with name 'pytorch-housing-manual-2' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/Users/mnozkiewicz/Magisterka/MLOPS/lab5/mlflow-artifacts/3', creation_time=1762722213523, experiment_id='3', last_update_time=1762722213523, lifecycle_stage='active', name='pytorch-housing-manual-2', tags={}>

# %% [markdown]
# ### 3.1 Targets transformation

# %% [markdown]
# Before training the neural network, we will transform the training target, in order to stabilize the training. To see why, let's plot the house prices:

# %%
y_train.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Training on such targets is possible, but very large target values easily risk overflow, particularly when a loss function like mean squared error is used. We will use the log-transform to transform this distribution, as it's near-exponential, so it should bring it closer to normal, and also greatly reduce the values range.
#
# Of course, we will need to transform the network predictions back again to evaluate them!

# %%
y_train_log = np.log1p(y_train)

pd.Series(y_train_log).plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### 3.2 Define and train the model

# %% [markdown]
# Since we have tabular data, we will use a simple 2-layer multilayer perceptron (MLP).

# %%
class HousePriceNet(nn.Module):
    def __init__(self, input_dim, hidden_dim=128, dropout_rate=0.2, **kwargs):
        super(HousePriceNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# For training, we will check both the 5-fold CV performance, and the traditional train-test split. Cross-validation will give us an additional, robust performance estimation, as well as standard deviation, which is useful for comparing performances of different models. After all, if the difference between models would be within one standard deviation, it wouldn't really be meaningful.

# %%
import torch.nn as nn


class PyTorchTrainer:
    def __init__(
        self, model_class: type[nn.Module], config: dict
    ):
        self.model_class = model_class
        self.config = config

    def create_model(self, input_dim: int) -> nn.Module:
        return self.model_class(
            input_dim=input_dim,
            **self.config
        )

    def create_data_loader(
        self, X: torch.Tensor, y: torch.Tensor, shuffle: bool = True
    ) -> DataLoader:
        dataset = TensorDataset(X, y)
        return DataLoader(
            dataset, batch_size=self.config["batch_size"], shuffle=shuffle
        )

    def train_epoch(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        criterion: nn.Module,
        optimizer: optim.Optimizer,
    ) -> float:
        model.train()
        epoch_loss = 0.0
        batch_count = 0

        for batch_X, batch_y in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            batch_count += 1

        return epoch_loss / batch_count

    def train_model(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        epochs: int,
        metric_prefix: str = "",
    ) -> None:
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=self.config["learning_rate"])

        for epoch in range(epochs):
            avg_mse = self.train_epoch(model, train_loader, criterion, optimizer)

            if epoch % self.config["log_interval"] == 0:
                metric_name = (
                    f"{metric_prefix}train_mse" if metric_prefix else "train_mse"
                )
                # manually log metric value, with a given name and step value
                mlflow.log_metric(metric_name, avg_mse, step=epoch)

    @torch.no_grad()
    def evaluate_model(
        self,
        model: nn.Module,
        X: torch.Tensor,
        y_test: torch.Tensor,
        log_prefix: str = "",
    ) -> dict[str, float]:
        model.eval()
        
        y_pred_norm = model(X)

        # revert the logarithm with exponent
        y_pred = np.expm1(y_pred_norm)
        y_pred = np.nan_to_num(y_pred, nan=0.0, posinf=1e10, neginf=-1e10)
        
        # y_test = y_test

        rmse = root_mean_squared_error(y_test.ravel(), y_pred.ravel())
        mae = mean_absolute_error(y_test.ravel(), y_pred.ravel())
        r2 = r2_score(y_test.ravel(), y_pred.ravel())

        if log_prefix:
            # manually log metrics that we want
            mlflow.log_metric(f"{log_prefix}_rmse", rmse)
            mlflow.log_metric(f"{log_prefix}_mae", mae)
            mlflow.log_metric(f"{log_prefix}_r2", r2)

        return {"rmse": rmse, "mae": mae, "r2": r2}

    def run_cross_validation(
        self, X_train: torch.Tensor, y_train: torch.Tensor, n_splits: int = 5
    ) -> tuple[float, float, list[float]]:
        kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
        cv_scores = []

        for fold, (train_idx, val_idx) in enumerate(kf.split(X_train)):
            print(f"\nTraining Fold {fold + 1}/{n_splits}...")

            X_fold_train = X_train[train_idx]
            y_fold_train = y_train[train_idx]
            X_fold_val = X_train[val_idx]
            y_fold_val = y_train[val_idx]

            fold_model = self.create_model(X_train.shape[1])
            fold_loader = self.create_data_loader(X_fold_train, y_fold_train)

            self.train_model(
                fold_model,
                fold_loader,
                self.config["epochs"],
                metric_prefix=f"fold_{fold + 1}_",
            )

            # transform validation data with exponent back to original unit
            y_fold_val = np.expm1(y_fold_val)
            y_fold_val = np.nan_to_num(y_fold_val, nan=0.0, posinf=1e10, neginf=-1e10)
            
            val_metrics = self.evaluate_model(
                fold_model, X_fold_val, y_fold_val, log_prefix=f"fold_{fold + 1}_val"
            )

            cv_scores.append(val_metrics["r2"])
            print(
                f"  Fold {fold + 1} "
                f"Validation - RMSE: {val_metrics['rmse']:.2f}, "
                f"MAE: {val_metrics['mae']:.2f} "
                f"R^2: {val_metrics['r2']:.3f}"
            )

        return np.mean(cv_scores), np.std(cv_scores), cv_scores

    def fit(
        self,
        X_train: pd.DataFrame | np.ndarray,
        y_train: pd.Series | np.ndarray,
        X_test: pd.DataFrame | np.ndarray,
        y_test: pd.Series | np.ndarray,
    ) -> dict:
        X_train, X_test, y_train, y_test = self._prepare_tensors(
            X_train, X_test, y_train, y_test
        )

        with mlflow.start_run(run_name=self.config["name"]):
            mlflow.log_params(self.config)

            print(f"Starting 5-fold cross-validation for {self.config['name']}...")
            cv_mean, cv_std, cv_scores = self.run_cross_validation(X_train, y_train)

            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)

            print(
                f"\nCross-validation complete. Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})"
            )
            print("\nTraining final model on all training data...")

            final_model = self.create_model(X_train.shape[1])
            final_loader = self.create_data_loader(X_train, y_train)

            self.train_model(
                final_model,
                final_loader,
                self.config["epochs"],
                metric_prefix="final_model_",
            )

            print("\nEvaluating on test set...")
            test_metrics = self.evaluate_model(final_model, X_test, y_test)

            mlflow.log_metric("test_rmse", test_metrics["rmse"])
            mlflow.log_metric("test_mae", test_metrics["mae"])
            mlflow.log_metric("test_r2", test_metrics["r2"])

            self._print_results(test_metrics, cv_mean, cv_std)

            return {
                "rmse": test_metrics["rmse"],
                "mae": test_metrics["mae"],
                "r2": test_metrics["r2"],
                "cv_r2_mean": cv_mean,
                "cv_r2_std": cv_std,
                "cv_scores": cv_scores,
            }

    def _prepare_tensors(self, X_train, X_test, y_train, y_test) -> tuple:
        y_train = np.array(y_train)
        y_test = np.array(y_test)
        
        X_train_tensor = torch.FloatTensor(X_train)
        y_train_tensor = torch.FloatTensor(y_train.reshape(-1, 1))
        
        X_test_tensor = torch.FloatTensor(X_test)
        y_test_tensor = torch.FloatTensor(y_test.reshape(-1, 1))

        print(f"Training samples: {X_train_tensor.shape[0]}")
        print(f"Input features: {X_train_tensor.shape[1]}")
        
        return X_train_tensor, X_test_tensor, y_train_tensor, y_test_tensor
    
    def _print_results(
        self, test_metrics: dict[str, float], cv_mean: float, cv_std: float
    ) -> None:
        print(f"{'=' * 50}\n")
        print(f"  Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})")
        print("\nCross-Validation Performance:")
        print(f"  R^2: {test_metrics['r2']:.3f}")
        print(f"  RMSE: {test_metrics['rmse']:.2f}")
        print(f"  MAE: {test_metrics['mae']:.2f}")
        print("Test Set Performance:")
        print(f"{'=' * 50}")
        print(f"FINAL RESULTS for {self.config['name']}:")
        print(f"\n{'=' * 50}")

# %% [markdown]
# Quite a bit of code there! So now let's train the model.

# %%
base_config = {
    "model_class": HousePriceNet,
    "random_seed": 42,
    "log_interval": 5,
    "num_samples": X_train.shape[0],
    "input_features": X_train.shape[1],
    "k_folds": 5,
}

config = {
    "name": "first_run",
    "hidden_units": 128,
    "dropout": 0.1,
    "learning_rate": 0.03,
    "epochs": 150,
    "batch_size": 32,
}

# %%
training_config = base_config | config

trainer = PyTorchTrainer(training_config["model_class"], training_config)
results = trainer.fit(X_train, y_train_log, X_test, y_test)
# Out:
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for first_run...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 23894.50, MAE: 16591.71 R^2: 0.921
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 19351.32, MAE: 13746.94 R^2: 0.939
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 28769.12, MAE: 18305.36 R^2: 0.877
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 24873.96, MAE: 16775.79 R^2: 0.892
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 23473.62, MAE: 16013.87 R^2: 0.905
#
# Cross-validation complete. Mean R^2: 0.907 (+/- 0.022)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.907 (+/- 0.022)
#
# Cross-Validation Performance:
#   R^2: 0.901
#   RMSE: 23795.81
#   MAE: 16799.69
# Test Set Performance:
# ==================================================
# FINAL RESULTS for first_run:
#
# ==================================================
# 🏃 View run first_run at: http://localhost:5000/#/experiments/3/runs/6d7cf53f61524ce3b9e6f8f0953cb635
# 🧪 View experiment at: http://localhost:5000/#/experiments/3

# %% [markdown]
# Go to the MLflow dashboard and take a look at logged values. Focus particularly on the "Model metrics" tab, which for neural networks visualizes the progress of iterative training.

# %% [markdown]
# ### 3.3 Hyperparameter optimization with MLflow

# %% [markdown]
# Now, we will use MLflow logging and visualization capabilities to help us tune hyperparameters of neural networks. This is one of the major applications of experiment tracking frameworks. As neural networks have many hyperparameters, with complex interactions, and training them many times is very computationally intensive, we want to use human judgment, based on plots and metrics, to guide our choices in further experiments.
#
# A quick recap on main hyperparameters of MLPs:
#
# 1. **Learning rate:**
#    - typically 1e-5 to 1e-1
#    - too high: loss explodes, model diverges
#    - too low: slow convergence, might get stuck
#    - sweet spot: fast convergence to good minimum
#
# 3. **Model size** - number of hidden units here:
#    - typically 32 to 512
#    - too few: underfitting, can't capture patterns
#    - too many: overfitting, slow training, diminishing returns
#    - consider: more features need more capacity
#
# 5. **Dropout rate:**
#    - typically 0.0 to 0.5
#    - 0.0: no regularization, risk overfitting
#    - too high: underfitting, loses important information
#    - purpose: prevents over-reliance on specific neurons
#
# 7. **Batch size:**
#    - typically 16 to 128
#    - small: noisy gradients, often better generalization, slower
#    - large: stable gradients, faster training, needs more memory, may overfit
#    - trade-off: speed vs generalization
#
# 9. **Number of epochs:**
#    - too few: underfitting
#    - too many: overfitting
#    - optimal: when validation loss stops improving
#    - watch validation loss

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# Your task is to:
# 1. Run 10 experiments by modifying the hyperparameter configuration. Try to improve model performance, which is currently overfitted.
# 2. Analyze results in MLflow UI.
# 3. Comment on what changes impacted the model performance the most, and what changes disrupted the training process.
# 4. Compare the results of our first scikit-learn configuration with the first PyTorch experiments. Do you see any overfitting in the first PyTorch experiment? Explain what signs of overfitting can indicate this situation.
#
# Example:
#
# ```python
#
# base_config = {
#     # or any other your own architecture :) we definitely recommend to experiment by yourselves
#     "model_class": HousePriceNet,
#     "random_seed": 42,
#     "log_interval": 5,
#     "input_features": X_train.shape[1],
#     "num_samples": X_train.shape[0],
#     "target_normalized": True,
#     "k_folds": 5,
# }
#
# configs = {
#      {
#         "name": "first_run_or_other_your_own_meaningful_name",
#         "hidden_units": 128,
#          ...
#      },
#     {
#         "name": "second_run_or...",
#         "hidden_units": 128,
#         "dropout": 0.1,
#         "learning_rate": 0.03,
#         "epochs": 150,
#         "batch_size": 32,
#     }
# }
#
# for config in configs:
#     # in python we can in elegant way merge two dicts using "|" operator - finally...
#     # old merging method {**base_config, **config} - ugly :(
#     training_config = base_config | config
#     trainer = PyTorchTrainer(training_config["model_class"], preprocessor, training_config)
#     results = trainer.fit(X_train, y_train, X_test, y_test)
# ```
#
# or just manually and incrementally:
#
# ```python
# new_config = {
#     "name": "second_run_or...",
#     "hidden_units": 128,
#     "dropout": 0.1,
#     "learning_rate": 0.03,
#     "epochs": 150,
#     "batch_size": 32,
# }
#
# training_config = base_config | config
# trainer = PyTorchTrainer(training_config["model_class"], preprocessor, training_config)
# results = trainer.fit(X_train, y_train, X_test, y_test)
# ```

# %%
from typing import Tuple

class HousePriceTestNet(nn.Module):

    def __init__(
            self, 
            input_dim: int, 
            hidden_dims: Tuple[int, ...] = (128,), 
            dropout_rate: float=0.2,
            **kwargs
        ):
        super().__init__()

        layers = []
        last_dim = input_dim
        relu = nn.ReLU()
        dropout = nn.Dropout(dropout_rate)

        for hidden_dim in hidden_dims:
            layers.extend([
                nn.Linear(last_dim, hidden_dim),
                relu,
                dropout
            ])

            last_dim = hidden_dim

        layers.append(nn.Linear(last_dim, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x)

# %%
base_config = {
    "model_class": HousePriceTestNet,
    "random_seed": 42,
    "log_interval": 5,
    "num_samples": X_train.shape[0],
    "input_features": X_train.shape[1],
    "k_folds": 5,
}

configs_one_layer = [
     {
        "name": "first_run_bigger_droput",
        "hidden_dims": (128,),
        "dropout": 0.2,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
     },
     {
        "name": "second_run_smaller_learning_rate",
        "hidden_dims": (128,),
        "dropout": 0.1,
        "learning_rate": 0.01,
        "epochs": 150,
        "batch_size": 32,
     },
     {
        "name": "third_run_bigger_batch",
        "hidden_dims": (128,),
        "dropout": 0.1,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 64,
     },
     {
        "name": "fourth_run_bigger_hidden_size",
        "hidden_dims": (256,),
        "dropout": 0.1,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
     },
]

for config in configs_one_layer:
    training_config = base_config | config 
    trainer = PyTorchTrainer(training_config["model_class"], training_config)
    results = trainer.fit(X_train, y_train_log, X_test, y_test)
# Out:
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for first_run_bigger_droput...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 39656.35, MAE: 29774.77 R^2: 0.782
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 22805.08, MAE: 16545.61 R^2: 0.915
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 24583.23, MAE: 18159.26 R^2: 0.910
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 22449.64, MAE: 15389.01 R^2: 0.912
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 24031.51, MAE: 15987.85 R^2: 0.901
#
# Cross-validation complete. Mean R^2: 0.884 (+/- 0.051)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.884 (+/- 0.051)
#
# Cross-Validation Performance:
#   R^2: 0.898
#   RMSE: 24127.82
#   MAE: 16270.69
# Test Set Performance:
# ==================================================
# FINAL RESULTS for first_run_bigger_droput:
#
# ==================================================
# 🏃 View run first_run_bigger_droput at: http://localhost:5000/#/experiments/3/runs/1791fb5c8b6348cd8fc0e08b74ae372c
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for second_run_smaller_learning_rate...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 57970.21, MAE: 44419.25 R^2: 0.534
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 44389.12, MAE: 35370.63 R^2: 0.677
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 45111.83, MAE: 32925.32 R^2: 0.697
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 35367.30, MAE: 26903.29 R^2: 0.781
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 40731.44, MAE: 28233.10 R^2: 0.714
#
# Cross-validation complete. Mean R^2: 0.681 (+/- 0.081)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.681 (+/- 0.081)
#
# Cross-Validation Performance:
#   R^2: 0.789
#   RMSE: 34700.30
#   MAE: 25008.06
# Test Set Performance:
# ==================================================
# FINAL RESULTS for second_run_smaller_learning_rate:
#
# ==================================================
# 🏃 View run second_run_smaller_learning_rate at: http://localhost:5000/#/experiments/3/runs/552cb6e67d9d4f7596f34ebe40e5ff46
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for third_run_bigger_batch...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 59635.87, MAE: 44127.12 R^2: 0.507
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 31865.33, MAE: 22682.04 R^2: 0.834
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 73405.30, MAE: 60746.05 R^2: 0.197
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 34329.78, MAE: 25128.16 R^2: 0.794
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 33701.00, MAE: 24591.37 R^2: 0.804
#
# Cross-validation complete. Mean R^2: 0.627 (+/- 0.245)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.627 (+/- 0.245)
#
# Cross-Validation Performance:
#   R^2: 0.517
#   RMSE: 52516.46
#   MAE: 42557.42
# Test Set Performance:
# ==================================================
# FINAL RESULTS for third_run_bigger_batch:
#
# ==================================================
# 🏃 View run third_run_bigger_batch at: http://localhost:5000/#/experiments/3/runs/30b7ecc2b8e94b7e892fae38d01dcdb7
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for fourth_run_bigger_hidden_size...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 38624.74, MAE: 29057.94 R^2: 0.793
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 23775.15, MAE: 17003.59 R^2: 0.907
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 36054.96, MAE: 23422.50 R^2: 0.806
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 24073.11, MAE: 16853.66 R^2: 0.899
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 32526.86, MAE: 24247.92 R^2: 0.818
#
# Cross-validation complete. Mean R^2: 0.845 (+/- 0.048)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.845 (+/- 0.048)
#
# Cross-Validation Performance:
#   R^2: 0.867
#   RMSE: 27600.17
#   MAE: 19849.65
# Test Set Performance:
# ==================================================
# FINAL RESULTS for fourth_run_bigger_hidden_size:
#
# ==================================================
# 🏃 View run fourth_run_bigger_hidden_size at: http://localhost:5000/#/experiments/3/runs/bd3c094cf37d49d0868430e452f3f3a4
# 🧪 View experiment at: http://localhost:5000/#/experiments/3

# %% [markdown]
# ![image.png](attachment:image.png)
#
# After the first batch of runs we can see that the only deviation from default parameters was increasing dropout.
# For the next batch I will try out similar changes as in the first but all with bigger dropout.

# %%
configs_bigger_dropouts = [
     {
        "name": "fith_run_even_bigger_droput",
        "hidden_dims": (128,),
        "dropout": 0.3,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
     },
     {
        "name": "sixth_run_smaller_learning_rate",
        "hidden_dims": (128,),
        "dropout": 0.2,
        "learning_rate": 0.01,
        "epochs": 150,
        "batch_size": 32,
     },
     {
        "name": "seventh_run_bigger_batch",
        "hidden_dims": (128,),
        "dropout": 0.2,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 64,
     },
     {
        "name": "eigth_run_bigger_hidden_size",
        "hidden_dims": (256,),
        "dropout": 0.2,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
     },
]

for config in configs_bigger_dropouts:
    training_config = base_config | config 
    trainer = PyTorchTrainer(training_config["model_class"], training_config)
    results = trainer.fit(X_train, y_train_log, X_test, y_test)
# Out:
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for fith_run_even_bigger_droput...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 23178.19, MAE: 15680.21 R^2: 0.926
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 22024.54, MAE: 15307.62 R^2: 0.920
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 24450.54, MAE: 16317.99 R^2: 0.911
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 25652.55, MAE: 17048.01 R^2: 0.885
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 23069.35, MAE: 15841.47 R^2: 0.908
#
# Cross-validation complete. Mean R^2: 0.910 (+/- 0.014)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.910 (+/- 0.014)
#
# Cross-Validation Performance:
#   R^2: 0.864
#   RMSE: 27874.23
#   MAE: 19667.22
# Test Set Performance:
# ==================================================
# FINAL RESULTS for fith_run_even_bigger_droput:
#
# ==================================================
# 🏃 View run fith_run_even_bigger_droput at: http://localhost:5000/#/experiments/3/runs/80e43438e6da4526852dae09f9a30cbd
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for sixth_run_smaller_learning_rate...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 37257.28, MAE: 27845.67 R^2: 0.808
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 41186.68, MAE: 30848.77 R^2: 0.722
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 54466.52, MAE: 41775.16 R^2: 0.558
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 43133.71, MAE: 30841.59 R^2: 0.674
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 41601.18, MAE: 31671.88 R^2: 0.702
#
# Cross-validation complete. Mean R^2: 0.693 (+/- 0.081)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.693 (+/- 0.081)
#
# Cross-Validation Performance:
#   R^2: 0.815
#   RMSE: 32504.98
#   MAE: 22579.96
# Test Set Performance:
# ==================================================
# FINAL RESULTS for sixth_run_smaller_learning_rate:
#
# ==================================================
# 🏃 View run sixth_run_smaller_learning_rate at: http://localhost:5000/#/experiments/3/runs/4db14344e4f544888733063e7d1c30bc
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for seventh_run_bigger_batch...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 53224.24, MAE: 41586.40 R^2: 0.607
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 73244.58, MAE: 63874.36 R^2: 0.121
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 38377.17, MAE: 26007.36 R^2: 0.781
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 115350.84, MAE: 77396.20 R^2: -1.329
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 34678.55, MAE: 26398.20 R^2: 0.793
#
# Cross-validation complete. Mean R^2: 0.195 (+/- 0.800)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.195 (+/- 0.800)
#
# Cross-Validation Performance:
#   R^2: 0.837
#   RMSE: 30530.64
#   MAE: 22813.08
# Test Set Performance:
# ==================================================
# FINAL RESULTS for seventh_run_bigger_batch:
#
# ==================================================
# 🏃 View run seventh_run_bigger_batch at: http://localhost:5000/#/experiments/3/runs/62b3c4dd51e34966a226eedf0078dc28
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for eigth_run_bigger_hidden_size...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 36949.12, MAE: 24091.85 R^2: 0.811
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 26050.74, MAE: 18684.57 R^2: 0.889
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 36668.25, MAE: 25842.22 R^2: 0.800
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 24210.86, MAE: 16311.38 R^2: 0.897
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 32082.46, MAE: 24275.31 R^2: 0.823
#
# Cross-validation complete. Mean R^2: 0.844 (+/- 0.041)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.844 (+/- 0.041)
#
# Cross-Validation Performance:
#   R^2: 0.898
#   RMSE: 24096.56
#   MAE: 16875.54
# Test Set Performance:
# ==================================================
# FINAL RESULTS for eigth_run_bigger_hidden_size:
#
# ==================================================
# 🏃 View run eigth_run_bigger_hidden_size at: http://localhost:5000/#/experiments/3/runs/8d69c4ce463e463388c699f376a98857
# 🧪 View experiment at: http://localhost:5000/#/experiments/3

# %% [markdown]
# ![image.png](attachment:image.png)
#
# No major improvements from the previous runs.

# %% [markdown]
# For the last two runs I will add the second hidden layer

# %%
configs_two_layers = [
     {
        "name": "ninth_run_two_layers",
        "hidden_dims": (256, 128),
        "dropout": 0.2,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
     },
     {
        "name": "tenth_run_two_layers_dropout",
        "hidden_dims": (256, 128,),
        "dropout": 0.3,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
     },
]

for config in configs_two_layers:
    training_config = base_config | config 
    trainer = PyTorchTrainer(training_config["model_class"], training_config)
    results = trainer.fit(X_train, y_train_log, X_test, y_test)
# Out:
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for ninth_run_two_layers...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 27358.91, MAE: 19369.54 R^2: 0.896
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 26854.54, MAE: 16764.49 R^2: 0.882
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 28313.36, MAE: 18867.70 R^2: 0.881
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 29782.79, MAE: 19253.01 R^2: 0.845
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 26916.63, MAE: 18942.28 R^2: 0.875
#
# Cross-validation complete. Mean R^2: 0.876 (+/- 0.017)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.876 (+/- 0.017)
#
# Cross-Validation Performance:
#   R^2: 0.893
#   RMSE: 24710.84
#   MAE: 16883.08
# Test Set Performance:
# ==================================================
# FINAL RESULTS for ninth_run_two_layers:
#
# ==================================================
# 🏃 View run ninth_run_two_layers at: http://localhost:5000/#/experiments/3/runs/987dc2558aff4809ab7acdae96c71297
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for tenth_run_two_layers_dropout...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 30702.93, MAE: 21490.67 R^2: 0.869
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 25330.29, MAE: 17132.32 R^2: 0.895
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 25876.27, MAE: 17777.03 R^2: 0.900
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 25786.28, MAE: 17658.41 R^2: 0.884
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 24281.90, MAE: 17576.20 R^2: 0.898
#
# Cross-validation complete. Mean R^2: 0.889 (+/- 0.012)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.889 (+/- 0.012)
#
# Cross-Validation Performance:
#   R^2: 0.864
#   RMSE: 27867.24
#   MAE: 21457.86
# Test Set Performance:
# ==================================================
# FINAL RESULTS for tenth_run_two_layers_dropout:
#
# ==================================================
# 🏃 View run tenth_run_two_layers_dropout at: http://localhost:5000/#/experiments/3/runs/1aac512ff3c14a5594bf340c6da1131b
# 🧪 View experiment at: http://localhost:5000/#/experiments/3

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# Seems like the default config remained the best up until the end.

# %% [markdown]
# ### Lab assessment
#
# Fill the code exercises in this Jupyter notebook, and send it with completed exercises, written comments in Markdown cells (particularly for questions in exercise 2), and screenshots of results in MLflow.
